# %%
import torch
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cpu

# %%
# Define slot values
difficulty = [
    "very easy", "easy", "medium", "not hard", "hard", "very hard",
    "flat and easy", "slightly challenging", "moderate effort",
    "somewhat tough", "difficult but rewarding", "challenging",
    "extreme difficulty", "intense"
]
meters = ['250 meters', '300 meters', '350 meters', '400 meters', '450 meters',
 '500 meters', '550 meters', '600 meters', '650 meters', '700 meters',
 '750 meters', '800 meters', '850 meters', '900 meters', '950 meters']
km_float = ['1.0 km', '2.0 km', '3.0 km', '4.0 km', '5.0 km', '6.0 km', '7.0 km', '8.0 km', '9.0 km',
 '10.0 km', '11.0 km', '12.0 km', '13.0 km', '14.0 km', '15.0 km', '16.0 km', '17.0 km', '18.0 km',
 '19.0 km', '20.0 km']
km_int = ['1 km', '1.5 km', '2 km', '2.5 km', '3 km', '3.5 km', '4 km', '4.5 km', '5 km', '5.5 km',
 '6 km', '6.5 km', '7 km', '7.5 km', '8 km', '8.5 km', '9 km', '9.5 km', '10 km', '10.5 km',
 '11 km', '11.5 km', '12 km', '12.5 km', '13 km', '13.5 km', '14 km', '14.5 km', '15 km', '15.5 km',
 '16 km', '16.5 km', '17 km', '17.5 km', '18 km', '18.5 km', '19 km', '19.5 km', '20 km']
kilometers_float=['1.0 kilometers', '2.0 kilometers', '3.0 kilometers', '4.0 kilometers', '5.0 kilometers', '6.0 kilometers', '7.0 kilometers', '8.0 kilometers', '9.0 kilometers',
 '10.0 kilometers', '11.0 kilometers', '12.0 kilometers', '13.0 kilometers', '14.0 kilometers', '15.0 kilometers', '16.0 kilometers', '17.0 kilometers', '18.0 kilometers',
 '19.0 kilometers', '20.0 kilometers']
kilometers_int= ['1 kilometers', '1.5 kilometers', '2 kilometers', '2.5 kilometers', '3 kilometers', '3.5 kilometers', '4 kilometers', '4.5 kilometers', '5 kilometers', '5.5 kilometers',
 '6 kilometers', '6.5 kilometers', '7 kilometers', '7.5 kilometers', '8 kilometers', '8.5 kilometers', '9 kilometers', '9.5 kilometers', '10 kilometers', '10.5 kilometers',
 '11 kilometers', '11.5 kilometers', '12 kilometers', '12.5 kilometers', '13 kilometers', '13.5 kilometers', '14 kilometers', '14.5 kilometers', '15 kilometers', '15.5 kilometers',
 '16 kilometers', '16.5 kilometers', '17 kilometers', '17.5 kilometers', '18 kilometers', '18.5 kilometers', '19 kilometers', '19.5 kilometers', '20 kilometers']
len_text=["short", "very short", "long", "very long", "medium-length",
    "under 1 km", "1-3 km", "3-5 km", "5-10 km", "10-15 km",
    "15-20 km", "over 20 km", "marathon length", "ultra marathon length",
    "quick run", "moderate distance", "long distance", "half-marathon length",
    "extremely long", "short sprint"
]
route_length = meters + km_float + km_int + kilometers_float + kilometers_int + len_text

# Expanded start locations
start_locations =  [
    "Jaffa Street",
    "King David Street",
    "Ben Yehuda Street",
    "King George Street",
    "Agripas Street",
    "Heleni HaMalka Street",
    "Ha-Nevi'im Street",
    "Shlomzion HaMalka Street",
    "Bezalel Street",
    "Hillel Street",
    "Shamai Street",
    "Prophets Street",
    "Via Dolorosa",
    "David Street",
    "Chain Street",
    "Al-Wad Street",
    "Malchei Israel Street",
    "Bar Ilan Street",
    "Shmuel HaNavi Street",
    "Herzl Boulevard",
    "Gaza Street",
    "Emek Refaim Street",
    "Bethlehem Road",
    "Pierre Koenig Street",
    "Hebron Road",
    "Derech Aza",
    "Ramban Street",
    "Jabotinsky Street",
    "Ussishkin Street",
    "Keren Hayesod Street",
    "Herzog Street",
    "HaPalmach Street",
    "Ha-Rav Berlin Street",
    "Beit HaKerem Street",
    "Sderot Eshkol",
    "Ruppin Boulevard",
    "Churchill Boulevard",
    "Begin Road",
    "Yitzhak Kariv Street",
    "Shivtei Israel Street",
    "Strauss Street",
    "Meah Shearim Street",
    "Malkhei Yisrael Street",
    "Hanevi'im Street",
    "Ethiopia Street",
    "Lincoln Street",
    "Washington Street",
    "Alfasi Street",
    "Rabbi Akiva Street",
    "Yad Harutzim Street",
    "Yirmiyahu Street",
    "Haim Bar Lev Road",
    "Tzfania Street",
    "Narkis Street",
    "Beit Hadfus Street",
    "HaTzanhanim Street",
    "Moshe Dayan Boulevard",
    "Rabin Boulevard",
    "Golda Meir Boulevard",
    "Ben Tzvi Boulevard",
    "Yigal Yadin Street",
    "Ahad Ha'am Street",
    "Bialik Street",
    "Tchernichovsky Street",
    "Weizmann Street",
    "Shazar Street",
    "Zalman Shneur Street",
    "Sderot HaRav Herzog",
    "Shlomo Zalman Shragai Street",
    "Sderot Levi Eshkol",
    "Sheshet Hayamim Street",
    "HaPisga Street",
    "Ha'Ayin Het Street",
    "Ha'Shayarot Street",
    "Shmuel Hanagid Street",
    "Herzl Street", "King George Street", "Ben Yehuda Street", "Weizmann Street",
    "Jabotinsky Street", "Dizengoff Street", "Allenby Street", "Rothschild Boulevard",
    "Ibn Gabirol Street", "Gordon Street", "Bialik Street", "Nordau Boulevard",
    "Arlozorov Street", "Ben Gurion Boulevard", "HaYarkon Street", "Kaplan Street",
    "Ahad Ha'am Street", "Sheinkin Street", "Levinsky Street", "Basel Street",
    "Yefet Street", "Bograshov Street", "Frishman Street", "Allenby Road",
    "HaHistadrut Street", "Begin Road", "Einstein Street", "Rabin Boulevard",
    "Golda Meir Boulevard", "Moshe Dayan Road", "Pinsker Street", "King Solomon Street",
    "Rashi Street", "Yehuda Halevi Street", "HaShalom Road", "Haifa Road",
    "Jerusalem Boulevard", "Tel Aviv Street", "Hashmonaim Street", "HaMelech Street",
    "Arlosoroff Street", "Sokolov Street", "Trumpeldor Street", "Balfour Street",
    "Usishkin Street", "HaNevi'im Street", "Yigal Alon Street", "Derech HaYam",
    "Nahalat Binyamin Street", "HaCarmel Street", "Shenkar Street", "Even Gvirol Street",
    "Hayarden Street", "HaGalil Street", "HaNegev Street", "Eilat Street",
    "Jaffa Road", "Gaza Road", "Bethlehem Road", "Hebron Road",
    "Pierre Koenig Street", "Emek Refaim Street", "Keren Hayesod Street", "Ramban Street",
    "Herzog Boulevard", "Palmach Street", "HaPalmach Street", "Kovshei Katamon Street",
    "Rachel Imenu Street", "Shimshon Street", "Yad Harutzim Street", "Bar Ilan Street",
    "Harav Kook Street", "Rabbi Akiva Street", "Malchei Israel Street", "Shmuel Hanavi Street",
    "Strauss Street", "Meah Shearim Street", "Geula Street", "Malkhei Yisrael Street",
]

additional_streets = [
    # Historical figures and leaders
    "Menachem Begin Street",
    "Yitzhak Shamir Street",
    "Levi Eshkol Street",
    "Chaim Weizmann Street",
    "Moshe Sharett Street",
    "Zalman Shazar Street",
    "Yigal Allon Street",
    "Abba Eban Street",
    "Moshe Sneh Street",
    "Berl Katznelson Street",

    # Military heroes
    "Yoni Netanyahu Street",
    "Hannah Szenes Street",
    "Eli Cohen Street",
    "Mickey Marcus Street",
    "Avraham Stern Street",
    "Yosef Trumpeldor Street",

    # Religious and cultural figures
    "Rambam Street",
    "Maimonides Street",
    "Rav Kook Street",
    "Baba Sali Street",
    "Rabbi Ovadia Yosef Street",
    "Rashi Street",
    "Ibn Ezra Street",
    "Yehuda Halevi Street",

    # Tribes and biblical references
    "Shimon Street",
    "Yehuda Street",
    "Menashe Street",
    "Efraim Street",
    "Dan Street",
    "Asher Street",
    "Zevulun Street",
    "Yissachar Street",

    # Geographic locations
    "Kinneret Street",
    "Carmel Street",
    "Gilboa Street",
    "Golan Street",
    "Negev Street",
    "Arava Street",
    "Galil Street",
    "Sharon Street",

    # Historical events
    "Balfour Street",
    "November 29th Street",
    "Independence Street",
    "Liberation Street",
    "Revival Street",
    "Unity Street",

    # Modern neighborhoods
    "Ramat Aviv Street",
    "Neve Tzedek Street",
    "Rehavia Street",
    "Talpiot Street",
    "Kiryat Yovel Street",
    "Katamon Street",
    "Baka Street",
    "Nachlaot Street",

    # Cultural institutions
    "Hebrew University Street",
    "Technion Street",
    "Habima Street",
    "Israel Museum Street",

    # Nature and agriculture
    "HaShaked Street",
    "HaGefen Street",
    "HaZayit Street",
    "HaRimon Street",
    "HaTamar Street",
    "HaBustan Street",

    # Cities and towns
    "Tiberias Street",
    "Safed Street",
    "Acre Street",
    "Beersheba Street",
    "Ashkelon Street",
    "Ashdod Street",
    "Netanya Street",
    "Herzliya Street",

    # Ancient sites
    "Masada Street",
    "Megiddo Street",
    "Caesarea Street",
    "Ein Gedi Street",

    # Valleys and mountains
    "Jezreel Street",
    "Jordan Valley Street",
    "Mount Carmel Street",
    "Mount Tabor Street",
    "Mount Hermon Street",

    # Modern heroes
    "Ilan Ramon Street",
    "Alice Miller Street",
    "Ada Yonath Street",
    "Daniel Kahneman Street",

    # Peace-related
    "Shalom Street",
    "Coexistence Street",
    "Peace Street",
    "Friendship Street"
]

more_streets = [
    # Prophets and Biblical Figures
    "Eliyahu HaNavi Street",
    "King Solomon Street",
    "Queen Esther Street",
    "King David Street",
    "Samuel HaNavi Street",
    "Isaiah Street",
    "Jeremiah Street",
    "Ezekiel Street",
    "Daniel Street",
    "Ruth Street",
    "Deborah Street",
    "Miriam HaNeviah Street",

    # Modern Cultural Figures
    "Naomi Shemer Street",
    "Ofra Haza Street",
    "Shai Agnon Street",
    "Leah Goldberg Street",
    "Rachel HaMeshoreret Street",
    "Chaim Nachman Bialik Street",
    "Uri Zvi Greenberg Street",
    "Nathan Alterman Street",

    # Scientists and Innovators
    "Albert Einstein Street",
    "Chaim Weizmann Street",
    "Aaron Aaronsohn Street",
    "Alexander Zarchin Street",
    "Marcus Reiner Street",
    "Dan Shechtman Street",

    # Early Zionist Leaders
    "Theodor Herzl Street",
    "Max Nordau Street",
    "Ze'ev Jabotinsky Street",
    "Ahad Ha'am Street",
    "Yehuda Leib Pinsker Street",
    "Arthur Ruppin Street",
    "Henrietta Szold Street",

    # IDF Generals and Military Heroes
    "Moshe Dayan Street",
    "Yitzhak Sadeh Street",
    "Yigael Yadin Street",
    "Haim Laskov Street",
    "David Elazar Street",
    "Mordechai Maklef Street",
    "Rafael Eitan Street",

    # Ancient Historical Sites
    "Gamla Street",
    "Tzipori Street",
    "Beit She'an Street",
    "Susya Street",
    "Tel Hazor Street",
    "Bet Alpha Street",
    "Tel Dan Street",

    # Water Sources
    "Ein Bokek Street",
    "Ein Avdat Street",
    "Ein Harod Street",
    "Ein Kerem Street",
    "Nahal Sorek Street",
    "Nahal Taninim Street",
    "Nahal Alexander Street",

    # Jewish Communities
    "Sephardim Street",
    "Kurdistan Street",
    "Morocco Street",
    "Yemen Street",
    "Bukhara Street",
    "Poland Street",
    "Hungary Street",

    # Israeli Industries
    "HaTaasiya Street",
    "HaMelacha Street",
    "HaHigh-Tech Street",
    "HaMada Street",
    "HaTechnology Street",
    "Innovation Street",

    # Local Flora
    "HaEucalyptus Street",
    "HaBrosh Street",
    "HaAlon Street",
    "HaDekel Street",
    "HaSycamore Street",
    "HaRotem Street",

    # Modern Neighborhoods
    "French Hill Street",
    "German Colony Street",
    "Yemin Moshe Street",
    "Mishkenot Sha'ananim Street",
    "Mamilla Street",
    "Abu Tor Street",

    # Archaeological Terms
    "Tel Aviv Street",
    "Tell Street",
    "Ancient Harbor Street",
    "Roman Cardo Street",
    "Byzantine Street",
    "Crusader Street",

    # Famous Markets
    "Machane Yehuda Street",
    "Carmel Market Street",
    "HaTikva Market Street",
    "Old City Market Street",
    "Ramle Market Street",

    # Modern Infrastructure
    "Light Rail Street",
    "Central Station Street",
    "Port Street",
    "Airport City Street",
    "Silicon Wadi Street",

    # Educational Institutions
    "Weizmann Institute Street",
    "Bar Ilan Street",
    "Ben Gurion University Street",
    "Technion Street",
    "Open University Street",

    # Medical Centers
    "Hadassah Street",
    "Shaare Zedek Street",
    "Ichilov Street",
    "Rambam Street",
    "Tel HaShomer Street",

    # Natural Reserves
    "Ein Gedi Reserve Street",
    "Hula Valley Street",
    "Ramon Crater Street",
    "Dead Sea Street",
    "Red Sea Street"
]

extra_streets = [
    # Artists and Musicians
    "Marcel Janco Street",
    "Reuven Rubin Street",
    "Yehudi Menuhin Street",
    "Arik Einstein Street",
    "Shoshana Damari Street",
    "Yehoram Gaon Street",
    "Yossi Banai Street",
    "Chava Alberstein Street",
    "Mordechai Zeira Street",

    # Resistance Fighters
    "Chana Senesh Street",
    "Haviva Reik Street",
    "Enzo Sereni Street",
    "Abba Kovner Street",
    "Mordechai Anielewicz Street",
    "Zivia Lubetkin Street",

    # Israeli Inventions
    "Drip Irrigation Street",
    "Solar Energy Street",
    "USB Street",
    "Firewall Street",
    "Waze Street",
    "ICQ Street",

    # Local Wildlife
    "HaYael Street",
    "HaNesher Street",
    "HaDov Street",
    "HaShual Street",
    "HaTzvi Street",
    "HaAyala Street",

    # Ancient Gates
    "Lions Gate Street",
    "Jaffa Gate Street",
    "Damascus Gate Street",
    "Zion Gate Street",
    "Herod's Gate Street",
    "New Gate Street",

    # Jewish Festivals
    "Pesach Street",
    "Sukkot Street",
    "Shavuot Street",
    "Purim Street",
    "Chanukah Street",
    "Simchat Torah Street",

    # Israeli Sports Figures
    "Tal Brody Street",
    "Yael Arad Street",
    "Esther Roth Street",
    "Gal Fridman Street",
    "Linoy Ashram Street",

    # Israeli Film Industry
    "Ephraim Kishon Street",
    "Uri Zohar Street",
    "Ari Folman Street",
    "Gila Almagor Street",
    "Chaim Topol Street",

    # Israeli Fashion
    "Maskit Street",
    "Gottex Street",
    "Fashion Week Street",
    "Textile Street",

    # Local Journalists
    "Uri Avnery Street",
    "Hannah Zemer Street",
    "Dov Yudkovsky Street",
    "Amos Schocken Street",

    # Economic Figures
    "Stef Wertheimer Street",
    "Dov Lautman Street",
    "Ted Arison Street",
    "Yossi Vardi Street",

    # Israeli Space Program
    "Space Center Street",
    "Satellite Street",
    "Ofek Street",
    "Shavit Street",
    "AMOS Street",

    # Israeli Dance
    "Inbal Street",
    "Batsheva Street",
    "Hora Street",
    "Mayim Street",
    "Dance Quarter Street",

    # Agriculture Pioneers
    "First Farmers Street",
    "Kibbutz Street",
    "Moshav Street",
    "Agricultural Station Street",
    "Farming Pioneer Street",

    # Israeli Architecture
    "Bauhaus Street",
    "White City Street",
    "Templar Street",
    "International Style Street",
    "Eclectic Style Street",

    # Local Spices and Herbs
    "HaZaatar Street",
    "HaSumsum Street",
    "HaKumin Street",
    "HaPaprika Street",
    "HaKurkum Street",

    # Desert Features
    "Sand Dune Street",
    "Desert Spring Street",
    "Acacia Valley Street",
    "Bedouin Path Street",
    "Oasis Street",

    # Israeli Theater
    "Habima Street",
    "Cameri Street",
    "Khan Theater Street",
    "Gesher Street",
    "Beit Lessin Street",

    # Israeli Literature Awards
    "Israel Prize Street",
    "Sapir Prize Street",
    "Jerusalem Prize Street",
    "Bialik Prize Street",

    # Israeli Technology Hubs
    "Startup Street",
    "Cyber Street",
    "Tech Park Street",
    "Innovation District Street",
    "Accelerator Street",

    # Famous Israeli Cafes
    "Cafe Tamar Street",
    "Cafe Kassit Street",
    "Cafe Roval Street",
    "Cafe Atara Street",

    # Israeli Publishing Houses
    "Schocken Street",
    "Keter Street",
    "Dvir Street",
    "Yedioth Street",
    "Maariv Street",
    "Shaare Ha'ir",
    "Ha-Nevi'im Street"
]

location_phrases = [
    # Current location phrases
    "my current location",
    "my location",
    "where I am",
    "where I am now",
    "my position",
    "current position",
    "here",
    "right here",
    "this spot",
    "this location",
    "my present location",
    "current place",
    "this place",
    "where I'm standing",
    "where I'm at",

    # Immediate vicinity phrases
    "near me",
    "around me",
    "around here",
    "this area",
    "this neighborhood",
    "my vicinity",
    "nearby",
    "in this area",
    "from where I am",

    # GPS related
    "my GPS location",
    "my coordinates",
    "my exact location",
    "my current coordinates",
    "my exact position",

    # Colloquial
    "from here",
    "where I'm located",
    "my current spot",
    "this point",
    "my whereabouts",
    "current whereabouts",
    "present position",
    "right where I am",
    "this current location"
]

start_locations+= additional_streets + more_streets + extra_streets + location_phrases

new_list = [item.replace('Street', '').strip() for item in start_locations if 'Street' in item]
start_locations += new_list
start_locations = list(map(str.lower, start_locations))
end_locations = start_locations.copy()
# Define templates
# Expanded set of templates for generating user input
templates = [
    "Create a {difficulty} running route from {start_location} {start_number} to {end_location} {end_number} that is {route_length}.",
    "I want to run {route_length} starting at {start_location} {start_number} and ending at {end_location} {end_number}, with {difficulty} difficulty.",
    "Can you generate a {difficulty} route from {start_location} {start_number} to {end_location} {end_number} with a distance of {route_length}?",
    "Plan a {difficulty} run between {start_location} {start_number} and {end_location} {end_number} for {route_length}.",
    "I'm looking for a {difficulty} run starting from {start_location} {start_number} to {end_location} {end_number}, covering {route_length}.",

    # More variations
    "Generate a {difficulty} running route from {start_location} {start_number} to {end_location} {end_number} that spans {route_length}.",
    "Please plan a {difficulty} run that starts at {start_location} {start_number} and ends at {end_location} {end_number} with a total distance of {route_length}.",
    "I need a {difficulty} running route from {start_location} {start_number} to {end_location} {end_number}, and the length should be {route_length}.",
    "Could you suggest a {difficulty} running route between {start_location} {start_number} and {end_location} {end_number}, covering {route_length}?",
    "Suggest a {difficulty} running route starting at {start_location} {start_number}, passing by {end_location} {end_number}, and lasting for {route_length}.",
    "Help me find a {difficulty} route that starts from {start_location} {start_number} and finishes at {end_location} {end_number} with a distance of {route_length}.",
    "I need a {difficulty} run starting at {start_location} {start_number}, heading to {end_location} {end_number}, and covering {route_length}.",
    "Can you create a {difficulty} route that begins at {start_location} {start_number} and finishes at {end_location} {end_number} with a distance of {route_length}?",
    "Plan a {difficulty} running route that starts at {start_location} {start_number} and ends at {end_location} {end_number}, with a length of {route_length}.",
    "Provide a {difficulty} running route that starts at {start_location} {start_number} and ends at {end_location} {end_number}, covering {route_length}.",
    "I'm looking for a {difficulty} route from {start_location} {start_number} to {end_location} {end_number} with a distance of {route_length}.",

    # Variations for difficulty, such as "easy", "moderate", etc.
    "Create an {difficulty} run from {start_location} {start_number} to {end_location} {end_number}, which is {route_length}.",
    "I want a {difficulty} route that goes from {start_location} {start_number} to {end_location} {end_number} and spans {route_length}.",
    "Generate a {difficulty} route for me from {start_location} {start_number} to {end_location} {end_number}, covering {route_length}.",
    "Can you suggest a {difficulty} running route from {start_location} {start_number} to {end_location} {end_number} with {route_length}?",

    # Only start location and route length
    "Create a running route from {start_location} {start_number} that is {route_length}.",
    "Can you suggest a route from {start_location} {start_number} with a distance of {route_length}?",
    "I want a running route starting at {start_location} {start_number} and covering {route_length}.",
    "Plan a route from {start_location} {start_number}, and make it {route_length}.",

    # Only end location and route length
    "Generate a running route to {end_location} {end_number} with a distance of {route_length}.",
    "I need a route ending at {end_location} {end_number} that covers {route_length}.",
    "Suggest a running route to {end_location} {end_number}, with a total distance of {route_length}.",
    "Can you provide a route to {end_location} {end_number} that spans {route_length}?",

    # Only difficulty and route length
    "Create a {difficulty} route that covers {route_length}.",
    "Generate a {difficulty} run that is {route_length}.",
    "I need a {difficulty} route of {route_length}.",
    "Can you suggest a {difficulty} run that spans {route_length}?",

    # Only difficulty and start location
    "Plan a {difficulty} run starting from {start_location} {start_number}.",
    "Suggest a {difficulty} route that begins at {start_location} {start_number}.",
    "I want a {difficulty} route from {start_location} {start_number}.",

    # Only start and end locations
    "Generate a running route from {start_location} {start_number} to {end_location} {end_number}.",
    "Can you create a route from {start_location} {start_number} to {end_location} {end_number}?",
    "I need a running route that goes from {start_location} {start_number} to {end_location} {end_number}.",
    "Please suggest a route from {start_location} {start_number} to {end_location} {end_number}.",

    # Only start location and difficulty
    "I need a {difficulty} running route starting from {start_location} {start_number}.",
    "Can you plan a {difficulty} route that begins at {start_location} {start_number}?",
    "Suggest a {difficulty} run from {start_location} {start_number}.",

    # Only end location and difficulty
    "Plan a {difficulty} route ending at {end_location} {end_number}.",
    "Can you create a {difficulty} run to {end_location} {end_number}?",
    "I want a {difficulty} route to {end_location} {end_number}.",

    # Only difficulty
    "Can you suggest a {difficulty} run?",
    "I need a {difficulty} route.",
    "Generate a {difficulty} running route.",

    # Only route length
    "Create a route that spans {route_length}.",
    "I want a running route of {route_length}.",
    "Plan a route of {route_length}.",
    "Generate a route with a distance of {route_length}.",

    # No slots at all (basic query without specifying any slot values)
    "Can you suggest a running route?",
    "Plan a running route for me.",
    "Please generate a route for running."
]

more_exampels_1= [
# Casual, conversational style
    "Hey, I wanna do a {route_length} run from {start_location} {start_number}, any good routes?",
    "Looking to knock out a {difficulty} {route_length} run starting near {start_location} {start_number}",
    "Need a solid {difficulty} route from {start_location} {start_number} to {end_location} {end_number}",
    "Got any decent {route_length} loops starting from {start_location} {start_number}?",

    # Running slang and terminology
    "Time for my long run - need a {difficulty} {route_length} route from {start_location} {start_number}",
    "Gotta get my miles in - show me a {route_length} loop from {start_location} {start_number}",
    "Looking to crush a {difficulty} {route_length} from {start_location} {start_number} to {end_location} {end_number}",
    "Need a recovery route around {route_length} near {start_location} {start_number}",

    # Specific scenarios
    "Training for a marathon - need a {difficulty} {route_length} route starting at {start_location} {start_number}",
    "Got an hour to kill - what's a good {route_length} route near {start_location} {start_number}?",
    "My usual route is boring, need a {difficulty} {route_length} alternative from {start_location} {start_number}",
    "Visiting the area - where can I do a quick {route_length} run near {start_location} {start_number}?",

    # Time-based queries
    "Need a morning route - something {difficulty} around {route_length} from {start_location} {start_number}",
    "Got time for a quick {route_length} run, starting at {start_location} {start_number}",
    "Looking for an after-work route, maybe {route_length} from {start_location} {start_number}",

    # Weather-related
    "It's hot today - got any shaded {route_length} routes from {start_location} {start_number}?",
    "Rainy day run - need a {difficulty} {route_length} route with good pavement from {start_location} {start_number}",

    # Group runs
    "Planning a group run, need a {difficulty} {route_length} route from {start_location} {start_number}",
    "Meeting friends for a run - what's a good {route_length} route near {start_location} {start_number}?",

    # Super casual
    "Yo, need a {route_length} route near {start_location} {start_number}",
    "What's the best way to do {route_length} starting from {start_location} {start_number}?",
    "Help a runner out - need a {difficulty} route from {start_location} {start_number}",

    # Specific needs
    "Need a route with water fountains, about {route_length} from {start_location} {start_number}",
    "Looking for a scenic {route_length} route near {start_location} {start_number}",
    "Want to avoid hills - got a flat {route_length} route from {start_location} {start_number}?",

    # Training specific
    "Need a tempo run route - {difficulty} {route_length} from {start_location} {start_number}",
    "Looking for some hill training - {difficulty} route around {route_length} from {start_location} {start_number}",
    "Easy recovery run - need a {route_length} route near {start_location} {start_number}",

    # Minimal info queries
    "Where should I run today?",
    "Need a quick running route",
    "Got any good routes nearby?",

    # Simple location-based
    "Where can I run near {start_location} {start_number}?",
    "Best running spots around {start_location} {start_number}?",
    "Show me some routes near {end_location} {end_number}",

    # Time-constrained
    "Got 30 mins - where should I run from {start_location} {start_number}?",
    "Quick lunch run route near {start_location} {start_number}?",
    "Need a short route from {start_location} {start_number}",

    # Safety focused
    "Need a well-lit route around {route_length} near {start_location} {start_number}",
    "Looking for a busy route for my evening run, about {route_length}",

    # Experience level specific
    "New runner here - need an easy {route_length} route near {start_location} {start_number}",
    "Advanced runner looking for a challenging {route_length} route from {start_location} {start_number}",

    # Social running
    "Planning a social run - need a {difficulty} {route_length} route with good stopping points",
    "Looking for a route with coffee shops along the way, around {route_length}",

    # Landmark-based
    "Want to run past {end_location} {end_number}, maybe {route_length} total?",
    "Need a route that includes {end_location} {end_number}, around {route_length}",

    # Training plan specific
    "Long run day - need a {difficulty} {route_length} route from {start_location} {start_number}",
    "Speed work route needed - {difficulty} {route_length} with good straightaways",
     # Super casual requests
    "Gonna do {route_length} today, where should I head from {start_location} {start_number}?",
    "Need inspo for my {route_length} run starting at {start_location} {start_number}",
    "Gimme a {difficulty} route around {route_length} near {start_location} {start_number}",
    "Help me plan my {route_length} run from {start_location} {start_number}?",

    # Daily running scenarios
    "First time running in this area, need a {route_length} route near {start_location} {start_number}",
    "Sick of my usual path, show me a {route_length} route from {start_location} {start_number}",
    "Running late but gotta get my miles in, quick {route_length} route from {start_location} {start_number}?",
    "Need a pre work route around {route_length} starting at {start_location} {start_number}",

    # Training specific
    "Marathon training calls for {route_length} today, starting from {start_location} {start_number}",
    "Coach says {route_length} {difficulty} run, got anything from {start_location} {start_number}?",
    "Building up mileage, need a {difficulty} {route_length} route near {start_location} {start_number}",
    "Time trial day, need a flat {route_length} route from {start_location} {start_number}",

    # Mood based
    "Feeling ambitious, show me a {difficulty} {route_length} route from {start_location} {start_number}",
    "Not feeling it today, got an easy {route_length} route near {start_location} {start_number}?",
    "Ready to crush it, give me a {difficulty} {route_length} starting at {start_location} {start_number}",

    # Social running
    "Crew run day, need a {route_length} route with photo ops near {start_location} {start_number}",
    "Running with newbies, need an easy {route_length} loop from {start_location} {start_number}",
    "Leading a group run, show me a {route_length} route from {start_location} {start_number}",

    # Time specific
    "Lunch break run, got 45 mins starting at {start_location} {start_number}",
    "Sunrise run route needed near {start_location} {start_number}, about {route_length}",
    "Late night run, need a safe {route_length} route from {start_location} {start_number}",

    # Location based
    "Just moved here, show me some {route_length} routes near {start_location} {start_number}",
    "On vacation but need to run {route_length} near {start_location} {start_number}",
    "At the office today, need a {route_length} lunch route from {start_location} {start_number}",

    # Goal oriented
    "Training for my first 5k, need a {route_length} route near {start_location} {start_number}",
    "Half marathon prep, looking for a {difficulty} {route_length} from {start_location} {start_number}",
    "Building endurance, show me a {difficulty} {route_length} route starting {start_location} {start_number}",

    # Terrain specific
    "Need some hills in my life, {route_length} route from {start_location} {start_number}?",
    "Looking for trail options around {route_length} near {start_location} {start_number}",
    "Beach run vibes today, got a {route_length} route near {start_location} {start_number}?",

    # Recovery focused
    "Easy day today, need a chill {route_length} route from {start_location} {start_number}",
    "Post race recovery run, something easy near {start_location} {start_number}",
    "Legs are toast, need a flat {route_length} route from {start_location} {start_number}",

    # Weather related
    "Brutal heat today, need a shady {route_length} route from {start_location} {start_number}",
    "Gonna rain later, quick {route_length} route from {start_location} {start_number}?",
    "Perfect running weather, show me a {route_length} route near {start_location} {start_number}",

    # Amenity focused
    "Need bathrooms along the way, {route_length} route from {start_location} {start_number}?",
    "Looking for drinking fountains on my {route_length} run from {start_location} {start_number}",
    "Coffee shop at the end please, {route_length} route from {start_location} {start_number}",

    # Simple requests
    "Where do people usually run around here?",
    "Show me the local running spots",
    "Need a good route for today",
    "What's a good running path nearby?",

    # Specific needs
    "Stroller friendly route needed around {start_location} {start_number}",
    "Running with my dog, need a {route_length} route near {start_location} {start_number}",
    "Got my headphones charged, ready for a {route_length} run from {start_location} {start_number}",

    # Time of day specific
    "Need a sunset route around {route_length} from {start_location} {start_number}",
    "Early bird run, show me a {route_length} route near {start_location} {start_number}",
    "Midnight runner here, safe {route_length} route from {start_location} {start_number}?",
    # Direct statements
    "I need a {route_length} route from {start_location} {start_number}",
    "Show me routes around {start_location} {start_number}",
    "Gonna run {route_length} from {start_location} {start_number} today",
    "Hook me up with a {difficulty} route from {start_location} {start_number}",

    # Training statements
    "Time for my long run from {start_location} {start_number}",
    "Doing {route_length} today starting at {start_location} {start_number}",
    "Need to get {route_length} in from {start_location} {start_number}",
    "Gotta do {route_length} for marathon training from {start_location} {start_number}",

    # Casual requests
    "Show me the best {route_length} route near {start_location} {start_number}",
    "Drop me a {difficulty} route from {start_location} {start_number}",
    "Trying to find a good {route_length} run near {start_location} {start_number}",
    "Just need a quick {route_length} route near {start_location} {start_number}",

    # Time-based
    "Got 30 minutes to run from {start_location} {start_number}",
    "Doing a quick lunch run from {start_location} {start_number}",
    "Running after work from {start_location} {start_number}",
    "Morning run starting at {start_location} {start_number}",

    # Direct needs
    "Need a route with bathrooms from {start_location} {start_number}",
    "Looking for a scenic {route_length} from {start_location} {start_number}",
    "Want a flat route from {start_location} {start_number}",
    "Need some hills in my run from {start_location} {start_number}",

    # Social running
    "Running with friends from {start_location} {start_number}",
    "Group run starting at {start_location} {start_number}",
    "Taking the run club from {start_location} {start_number}",
    "Doing a social run from {start_location} {start_number}",

    # Training specific
    "Doing speedwork from {start_location} {start_number}",
    "Easy recovery run from {start_location} {start_number}",
    "Long run Sunday starting at {start_location} {start_number}",
    "Tempo run from {start_location} {start_number}",

    # Weather based
    "Need a shaded route from {start_location} {start_number}",
    "Want to avoid muddy trails from {start_location} {start_number}",
    "Looking for covered paths from {start_location} {start_number}",

    # Simple statements
    "Show me where to run",
    "Need a route for today",
    "Just want somewhere new to run",
    "Time for my daily run",

    # Location based
    "First time running in this area",
    "Never run here before need a route",
    "Show me the local running spots",
    "Taking a different route today from {start_location} {start_number}",

    # Specific needs
    "Running with my dog from {start_location} {start_number}",
    "Taking the stroller today from {start_location} {start_number}",
    "Need a route with street lights from {start_location} {start_number}",

    # Direct commands
    "Map me a route from {start_location} {start_number}",
    "Give me a {route_length} route",
    "Find me somewhere to run {route_length}",
    "Make me a route from {start_location} {start_number}",

    # Very casual
    "Yo need a route from {start_location} {start_number}",
    "Time to run hit me with a route",
    "Bout to head out from {start_location} {start_number}",
    "Ready to run from {start_location} {start_number}",

    # Goal oriented
    "Training for a marathon from {start_location} {start_number}",
    "Getting ready for a 5k need a route",
    "Building up to {route_length} from {start_location} {start_number}",
    "Prepping for race day from {start_location} {start_number}",

    # Mood based
    "Feeling good need a {difficulty} route",
    "Ready to crush {route_length} from {start_location} {start_number}",
    "Taking it easy today from {start_location} {start_number}",
    "Lets go running from {start_location} {start_number}"
]

more_examples_2 = [
    "I want to run from {start_location} {start_number} to {end_location} {end_number}, need {route_length} {difficulty} route",
    "pls make running route {difficulty} about {route_length} starting {start_location} {start_number} ending {end_location} {end_number}",
    "hi can u plan {difficulty} run {route_length} from {start_location} {start_number} to {end_location} {end_number}",
    "need {difficulty} jogging route {route_length} starting {start_location} {start_number} finish at {end_location} {end_number}",
    "looking for {difficulty} running path {route_length} from {start_location} {start_number} to {end_location} {end_number}",
    "elderly runner here want {difficulty} track {route_length} start {start_location} {start_number} end {end_location} {end_number}",
    "experienced marathoner seeking {difficulty} route {route_length} beginning {start_location} {start_number} finishing {end_location} {end_number}",
    "first time in israel need {difficulty} path {route_length} from {start_location} {start_number} 2 {end_location} {end_number}",
    "want {difficulty} run {route_length} starting point {start_location} {start_number} endpoint {end_location} {end_number}",
    "make me route plz {difficulty} like {route_length} from {start_location} {start_number} until {end_location} {end_number}",
    "senior citizen requesting {difficulty} course {route_length} starting {start_location} {start_number} ending {end_location} {end_number}",
    "competitive runner need {difficulty} track {route_length} from {start_location} {start_number} to {end_location} {end_number}",
    "tourist here want {difficulty} route {route_length} begin {start_location} {start_number} end {end_location} {end_number}",
    "gimme {difficulty} path {route_length} start {start_location} {start_number} finish {end_location} {end_number}",
    "need simple {difficulty} route {route_length} from {start_location} {start_number} to {end_location} {end_number}",
    "advanced runner want {difficulty} course {route_length} beginning {start_location} {start_number} end at {end_location} {end_number}",
    "older person need {difficulty} path {route_length} start {start_location} {start_number} finish {end_location} {end_number}",
    "can u make {difficulty} running route {route_length} from {start_location} {start_number} 2 {end_location} {end_number}",
    "plan running route {difficulty} distance {route_length} starting {start_location} {start_number} ending {end_location} {end_number}",
    "need route 4 beginner {difficulty} about {route_length} from {start_location} {start_number} to {end_location} {end_number}",
    "xperienced runner want {difficulty} path {route_length} start {start_location} {start_number} finish {end_location} {end_number}",
    "first time runner here need {difficulty} track {route_length} from {start_location} {start_number} 2 {end_location} {end_number}",
    "make me {difficulty} route {route_length} beginning {start_location} {start_number} end point {end_location} {end_number}",
    "senior runner want {difficulty} path {route_length} start {start_location} {start_number} finish {end_location} {end_number}",
    "need pro level {difficulty} course {route_length} from {start_location} {start_number} to {end_location} {end_number}",
    "newbie here want {difficulty} route {route_length} start {start_location} {start_number} end {end_location} {end_number}",
    "plz plan {difficulty} path {route_length} from {start_location} {start_number} 2 {end_location} {end_number}",
    "tourist need {difficulty} track {route_length} beginning {start_location} {start_number} finishing {end_location} {end_number}",
    "advanced athlete want {difficulty} route {route_length} from {start_location} {start_number} to {end_location} {end_number}",
    "elderly person need {difficulty} path {route_length} start {start_location} {start_number} end {end_location} {end_number}",
    "i want to run {route_length} from {start_location} to {end_location}",
    "make me {difficulty} route from {start_location} {start_number}",
    "{difficulty} running track please",
    "need run starting at {start_location} {start_number} that is {difficulty}",
    "plan {route_length} route ending at {end_location} {end_number}",
    "runner here looking for {difficulty} path {route_length}",
    "start from {start_location} {start_number} to {end_location}",
    "{route_length} easy run plz",
    "need route starting {start_location} ending {end_location} {end_number}",
    "want {difficulty} track about {route_length}",
    "from {start_location} {start_number} need {difficulty} path",
    "running route {route_length} to {end_location} {end_number}",
    "can u make {difficulty} route from {start_location}",
    "{route_length} to {end_location} {end_number} please",
    "senior runner need route from {start_location} {start_number}",
    "{difficulty} run ending at {end_location}",
    "make me {route_length} path please",
    "start {start_location} {start_number} {difficulty}",
    "route to {end_location} thats {difficulty}",
    "{route_length} run from {start_location} {start_number}",
    "beginner want {difficulty} run",
    "plan route ending {end_location} {end_number}",
    "need {route_length} {difficulty} path",
    "{start_location} {start_number} to {end_location}",
    "looking for {difficulty} track",
    "run from {start_location} to {end_location} {end_number}",
    "{route_length} route please",
    "make path from {start_location} {start_number}",
    "{difficulty} run {route_length}",
    "to {end_location} {end_number} please",
    "need {route_length} track",
    "{start_location} to {end_location}",
    "want {difficulty} path please",
    "run starting {start_location} {start_number}",
    "{route_length} to {end_location}",
    "make me {difficulty} route please",
    "{start_location} {start_number} run",
    "need {route_length} {difficulty}",
    "route to {end_location} {end_number}",
    "{difficulty} from {start_location}",
    "simple run {route_length}",
    "{start_location} to {end_location} run",
    "make me {difficulty} path",
    "{route_length} ending {end_location} {end_number}",
    "start at {start_location} {start_number}",
    "need {difficulty} {route_length}",
    "running to {end_location}",
    "{start_location} {start_number} path",
    "want {route_length} track please",
    "{difficulty} route to {end_location} {end_number}",
    "I need a running route in tel aviv",
    "{start_location} {start_number} to {end_location} {end_number}, want {difficulty} run about {route_length}",
    "hey can you help me find a nice running track?",
    "looking for {difficulty} route {route_length}",
    "i wanna run from my house on {start_location} to the beach",
    "make me something challenging please",
    "{route_length} route from {start_location} {start_number} to {end_location} {end_number}, not too hard",
    "first time runner here need help",
    "gimme a {difficulty} route {route_length}",
    "can u plan my morning jog?",
    "{start_location} {start_number} to {end_location} {end_number}, {difficulty} please",
    "need a quick {route_length} run",
    "plan me something from {start_location} {start_number}",
    "im training for marathon need hard route",
    "{difficulty} path {route_length} from {start_location} {start_number} to {end_location} {end_number}",
    "elderly person looking for nice walking route",
    "start at {start_location} going to beach",
    "need route for tomorrow morning",
    "{route_length} {difficulty} run from {start_location} please",
    "can you suggest good running path?",
    "{start_location} {start_number} to {end_location} {end_number}, {route_length} {difficulty}",
    "where should i run today?",
    "planning my evening jog need suggestions",
    "{difficulty} route {route_length} starting {start_location} {start_number}",
    "beginner runner need help with route",
    "from my place on {start_location} to the park",
    "{route_length} easy path please",
    "want to run but dont know where",
    "{start_location} {start_number} to {end_location} {end_number}, {difficulty} {route_length}",
    "recommend me a good running track",
    "need {difficulty} route for my mom",
    "planning 5k where should i go",
    "{start_location} {start_number} to {end_location} {end_number}",
    "first time in tel aviv want to go running",
    "{difficulty} {route_length} route please",
    "help me plan my run",
    "from {start_location} {start_number} to {end_location} {end_number}, make it {difficulty}",
    "need a route for tomorrow",
    "{route_length} path somewhere nice",
    "tourist looking for running route",
    "{start_location} {start_number} to {end_location} {end_number}, {route_length} {difficulty}",
    "where do people usually run here?",
    "need {difficulty} track for morning jog",
    "recommend running route please",
    "{start_location} {start_number} to {end_location} {end_number}",
    "im new here where should i run?",
    "{route_length} {difficulty} route needed",
    "quick running path suggestion please",
    "{start_location} {start_number} to {end_location} {end_number}, {difficulty}",
    "need route for evening run",
    "something {difficulty} around {route_length}",
    "where to run in tel aviv?",
    "{start_location} {start_number} to {end_location} {end_number}, {route_length}",
    "running route recommendations?",
    "{difficulty} path from {start_location}",
    "help plan my morning exercise",
    "{route_length} {difficulty} route from {start_location} {start_number} to {end_location} {end_number}",
    "new to running need advice",
    "good places to run around here?",
    "{start_location} {start_number} to {end_location}",
    "need {route_length} track",
    "wheres good for morning jog?",
    "{difficulty} route from {start_location} {start_number}",
    "simple running path please",
    "{route_length} from {start_location} {start_number} to {end_location} {end_number}, {difficulty}",
    "suggest route for beginner",
    "where to run {route_length}?",
    "{start_location} to beach route",
    "need {difficulty} morning run",
    "plan my run from {start_location} {start_number} to {end_location} {end_number}, {route_length}",
    "good running spots in the city?",
    "{difficulty} {route_length} please",
    "recommend safe running route",
    "{start_location} {start_number} to {end_location} {end_number}",
    "need running path suggestion",
    "where can i do {route_length} run?",
    "route planning help please",
    "{start_location} {start_number} to {end_location} {end_number}, {difficulty} {route_length}",
    "best places to run here?",
    "something {difficulty} and short",
    "running track near {start_location}",
    "{route_length} path suggestion",
    "need help planning route",
    "{start_location} {start_number} to {end_location} {end_number}, {difficulty}",
    "where should i start my run?",
    "{route_length} {difficulty} track needed",
    "good running route for tourists?",
    "{start_location} {start_number} to {end_location} {end_number}",
    "running path recommendation",
    "need {difficulty} route about {route_length}",
    "suggest good running spot",
    "{start_location} {start_number} to {end_location} {end_number}, {difficulty}",
    "where do locals run?",
    "need {route_length} easy route",
    "running track suggestions?",
    "{start_location} {start_number} to {end_location} {end_number}, {difficulty} {route_length}",
    "help me find running route",
    "good path for morning run?",
    "{difficulty} route somewhere nice",
    "need running suggestions please",
    "Hey there, I'm looking for a {difficulty} running route that starts from {start_location} {start_number} and goes all the way to {end_location} {end_number}, something around {route_length} would be perfect",
    "I'm visiting Tel Aviv for the first time and would love to go for a morning run tomorrow",
    "Could you help me plan a {difficulty} route for my training? I live near {start_location} {start_number} and want to run about {route_length}",
    "Looking for a nice scenic route that goes from {start_location} {start_number} to {end_location} {end_number}, preferably {difficulty} since I'm just getting back into running",
    "Hi! I've been running for years and need a {difficulty} training route that's about {route_length}, starting from my apartment on {start_location}",
    "Can you suggest a nice morning running path that's not too difficult? Maybe around {route_length} somewhere near the beach?",
    "Need a {route_length} route from {start_location} {start_number} to {end_location} {end_number} that's {difficulty} level - training for a race next month",
    "First time runner here, would appreciate a beginner-friendly route somewhere scenic in the city",
    "Planning my weekend long run, need a {difficulty} path from {start_location} {start_number} to {end_location} {end_number}, about {route_length}",
    "My doctor recommended daily walks - could you suggest an easy route near the city center?",
    "Looking for a {route_length} running track that starts at {start_location} {start_number} and has some nice city views along the way",
    "Need to prepare for my marathon - can you plan a {difficulty} route around {route_length} starting from {start_location}?",
    "Hey, I'm staying near {start_location} {start_number} and would love a {difficulty} morning running route to {end_location} {end_number}",
    "Can anyone recommend a good running path for a tourist? Staying in a hotel on {start_location} and want to explore the city",
    "Looking for a {route_length} route with {difficulty} intensity that shows off the best parts of Tel Aviv",
    "Need a running route for tomorrow morning - something {difficulty} from {start_location} {start_number} to {end_location} {end_number}",
    "Hi there, I'm training for a half marathon and need a {difficulty} route about {route_length}, preferably near the beach",
    "Could you suggest a nice evening running path that starts from {start_location} {start_number} and isn't too strenuous?",
    "Looking for a scenic route that's approximately {route_length} and {difficulty} - my mom is visiting and wants to go for a walk",
    "Need a good running track for my morning exercise - something that starts near {start_location} and is moderately challenging",
    "Hey there! I'm a business traveler staying at a hotel on {start_location} {start_number} and would love a {difficulty} route to {end_location} {end_number}",
    "Planning my weekend fitness routine and need a nice {route_length} path with some interesting city views",
    "I'd really appreciate a {difficulty} running route from {start_location} {start_number} that passes through some historic areas",
    "Looking for recommendations for a good morning run - something around {route_length} and not too difficult for a beginner",
    "Can you help plan a route? I live near {start_location} {start_number} and want to run to {end_location} {end_number}, maybe {difficulty} level",
    "hi can u make me a {difficulty} route?",
    "Looking for a {route_length} path from {start_location} {start_number} to {end_location} {end_number}, something not too challenging for my morning exercise",
    "where should i run in tel aviv?",
    "{start_location} {start_number} to {end_location} {end_number}, {difficulty} {route_length} please and thank you!",
    "need running recommendations near the beach",
    "Hey! I'm training for a marathon and need a {difficulty} route that's about {route_length}",
    "first time runner here, any suggestions?",
    "{start_location} {start_number} to {end_location}, something easy please",
    "can u plan me a quick 5k run?",
    "Looking for a nice {difficulty} path from {start_location} {start_number} that's good for elderly people",
    "need route for tomorrow morning run",
    "{route_length} {difficulty} track from {start_location} {start_number} to {end_location} {end_number}",
    "what's a good running spot around here?",
    "I'm staying at {start_location} {start_number} and would love a {difficulty} route to explore the city",
    "beginner runner needs help with route planning",
    "{start_location} {start_number} to {end_location} {end_number}, make it {route_length} and {difficulty}",
    "recommend me somewhere nice to run",
    "Need a {difficulty} path that starts from {start_location} {start_number}",
    "where do locals usually run?",
    "{route_length} {difficulty} route from {start_location} {start_number} to {end_location} {end_number}",
    "tourist here - need help finding good running spots!",
    "{difficulty} {route_length} path starting {start_location} {start_number} ending {end_location} {end_number}",
    "looking for a nice morning jog route nothing too crazy",
    "need a {difficulty} path from {start_location} {start_number} to {end_location} {end_number} that's {route_length}",
    "hey can u suggest where to run around here",
    "{start_location} {start_number} to beach, something easy please",
    "Looking for a nice running route that's good for beginners",
    "{difficulty} {route_length} from {start_location} {start_number} to {end_location} {end_number}",
    "first time in tel aviv where should i go running?",
    "need {route_length} path near the water",
    "{start_location} {start_number} to {end_location} {end_number}, make it {difficulty}",
    "planning my morning exercise need suggestions",
    "experienced runner looking for {difficulty} route about {route_length}",
    "can you recommend nice running spots?",
    "{start_location} {start_number} to {end_location} {end_number}, {difficulty} {route_length} please",
    "wheres good for evening jog?",
    "need {difficulty} track starting from {start_location} {start_number}",
    "training for marathon need long route",
    "{route_length} {difficulty} path from {start_location} {start_number} to {end_location} {end_number}",
    "elderly person needs walking route suggestion",
    "where do people usually run in morning?",
    "{start_location} {start_number} to {end_location} {end_number}, something {difficulty}",
    "help plan my first 5k route",
    "looking for {route_length} run with nice views",
    "new to running need beginner route",
    "{difficulty} path from {start_location} {start_number} to {end_location} {end_number}, {route_length}",
    "suggest good spots for morning exercise",
    "want route from {start_location} that's not too hard",
    "planning weekend run need ideas",
    "{route_length} {difficulty} track starting {start_location} {start_number}",
    "tourist needs running recommendations",
    "{difficulty} route to {end_location} {end_number}",
    "where can i do short easy run?",
    "{start_location} {start_number} to {end_location} {end_number}, {route_length} please",
    "need route for tomorrow's training",
    "looking for {difficulty} path about {route_length}",
    "recommend safe running areas please",
    "{start_location} {start_number} to {end_location} {end_number}, make it {difficulty}",
    "first timer needs running advice",
    "{route_length} track with good scenery",
    "staying near {start_location} need running route",
    "{difficulty} path to {end_location} {end_number}",
    "where to run for good city views?",
    "{start_location} {start_number} to {end_location} {end_number}, {route_length} {difficulty}",
    "need quick morning run suggestion",
    "plan me something {difficulty} around {route_length}",
    "good running track for photography",
    "{start_location} {start_number} to {end_location} {end_number}, not too difficult",
    "looking for peaceful running route",
    "{route_length} {difficulty} path please",
    "Hi there! I'm staying at a hotel near {start_location} {start_number} and would love a {difficulty} running route to {end_location} {end_number} that's about {route_length} - preferably with some nice cafes along the way",
    "Good morning! I've just moved to Tel Aviv and I'm looking for a nice running route that shows off the best parts of the city - any suggestions?",
    "Planning my weekend long run and need a {difficulty} path that starts from {start_location} {start_number} and goes to {end_location} {end_number}, hoping for something around {route_length} with some scenic spots",
    "Hey running friends! I'm training for my first 5K and would love some recommendations for a beginner-friendly route near the beach area",
    "Could you help plan a {route_length} route from {start_location} {start_number} to {end_location} {end_number}? Looking for something {difficulty} with not too many traffic lights",
    "I'm visiting from America for a week and staying near {start_location} - would love suggestions for a morning running route with good views of the city",
    "Need a {difficulty} training route that's about {route_length} starting from {start_location} {start_number} and ending at {end_location} {end_number} - preparing for an upcoming marathon",
    "Hello! My elderly parents are visiting next week and I'd love to find a {difficulty} walking route around the historic areas of the city",
    "Looking for a nice morning running path that starts from my apartment on {start_location} {start_number} and heads towards the sea - something around {route_length} would be perfect",
    "Can anyone recommend a good {difficulty} running route that shows off the city's architecture? Staying near {start_location} {start_number}",
    "First-time runner here looking for a beginner-friendly route without too many hills - maybe starting from {start_location} and heading towards the beach area?",
    "Planning a {route_length} {difficulty} run from {start_location} {start_number} to {end_location} {end_number} - would love something with good morning light for photos",
    "Hi runners! Visiting Tel Aviv next month and would love some suggestions for scenic routes that aren't too tourist-heavy - preferably {difficulty} difficulty",
    "Need help planning tomorrow's run - something that starts from {start_location} {start_number} and is about {route_length} with some interesting neighborhoods along the way",
    "Looking for a running route that passes by some good breakfast spots - starting from {start_location} {start_number} and heading towards {end_location} {end_number}",
]

templates +=more_exampels_1 + more_examples_2

# %% [markdown]
# Dataset Summary

# %%
print("Dataset Summary:")
print(f"Number of templates: {len(templates)}")
print(f"Number of difficulty levels: {len(difficulty)}")
print(f"Number of route lengths: {len(route_length)}")
print(f"Number of start locations: {len(start_locations)}")
print(f"Number of end locations: {len(end_locations)}")
# Out:
# Dataset Summary:
# Number of templates: 499
# Number of difficulty levels: 14
# Number of route lengths: 153
# Number of start locations: 944
# Number of end locations: 944

# %%
num_of_examples = 30000
file_name="crafted_dataset_30k.csv"

# %%
import random
# Generate user inputs
sentences = []
for _ in range(num_of_examples):  # Generate examples
    template = random.choice(templates)

    # Randomly select values
    difficulty_value = random.choice(difficulty)
    route_length_value = random.choice(route_length)
    start_location_value = random.choice(start_locations)
    end_location_value = random.choice(end_locations)

    # Check if start_location or end_location are in location_phrases
    start_number_value = '' if start_location_value in location_phrases else f"loca_start_num: {random.randint(1, 100)}"
    end_number_value = '' if end_location_value in location_phrases else f"loca_end_num: {random.randint(1, 100)}"

    # Format and append the sentence
    sentences.append(
        template.format(
            difficulty=f"{{difficulty: {difficulty_value}}}",
            route_length=f"{{route_length: {route_length_value}}}",
            start_location=f"{{start_location: {start_location_value}}}",
            end_location=f"{{end_location: {end_location_value}}}",
            start_number=f"{{{start_number_value}}}",
            end_number=f"{{{end_number_value}}}"
        )
    )


for i in range(0, min(num_of_examples, 10)):
    print(f"{i+1}. {sentences[i]}")  # Print the 1-based index

print("*"*100)
print("                                            DONE!")
print("*"*100)
# Out:
# 1. Map me a route from {start_location: yitzhak sadeh} {loca_start_num: 12}
# 2. Easy recovery run from {start_location: strauss street} {loca_start_num: 48}
# 3. At the office today, need a {route_length: 15 km} lunch route from {start_location: abu tor street} {loca_start_num: 74}
# 4. Never run here before need a route
# 5. Can anyone recommend a good running path for a tourist? Staying in a hotel on {start_location: miriam haneviah} and want to explore the city
# 6. suggest good spots for morning exercise
# 7. recommend me a good running track
# 8. can you recommend nice running spots?
# 9. quick running path suggestion please
# 10. make me {route_length: 10.0 km} path please
# ****************************************************************************************************
#                                             DONE!
# ****************************************************************************************************

# %%
sentences = [sentence.replace(" {}", "") for sentence in sentences]
import re

def extract_entities(sentence):
    """
    Extract entities from the sentence, e.g., {difficulty: easy}.
    Returns a list of tuples containing (entity_type, entity_value) and their positions in the sentence.
    """
    matches = [(match.start(), match.end(), *re.match(r'\{(\w+): ([^\}]+)\}', match.group()).groups())
               for match in re.finditer(r'\{(\w+): [^\}]+\}', sentence)]
    return matches

def tokenize_with_entities(sentence):
    """
    Tokenize the sentence while handling entities and generating BIO tags.
    """
    tokens = []
    bio_tags = []
    current_index = 0

    # Extract entities with positions
    entities = extract_entities(sentence)

    # Iterate over entities and plain text
    for start, end, entity_type, entity_value in entities:
        # Process plain text before the entity
        plain_text = sentence[current_index:start].strip()
        if plain_text:
            plain_tokens = plain_text.split()
            tokens.extend(plain_tokens)
            bio_tags.extend(['O'] * len(plain_tokens))

        # Process entity tokens
        entity_tokens = entity_value.split()
        tokens.extend(entity_tokens)
        bio_tags.append(f"B-{entity_type}")
        bio_tags.extend([f"I-{entity_type}"] * (len(entity_tokens) - 1))

        # Update current index
        current_index = end

    # Process remaining plain text after the last entity
    plain_text = sentence[current_index:].strip()
    if plain_text:
        plain_tokens = plain_text.split()
        tokens.extend(plain_tokens)
        bio_tags.extend(['O'] * len(plain_tokens))

    return tokens, bio_tags

def process_sentences(arr):
    result = []

    for sentence in arr:
        sentence = sentence.strip()
        tokens, bio_tags = tokenize_with_entities(sentence)
        result.append({'sentence': sentence, 'tokens': tokens, 'bio_tags': bio_tags})

    return result

# Process the sentences
processed_sentences = process_sentences(sentences)

# Display results
for i, obj in enumerate(processed_sentences, start=1):
    print(f"{i}. sentence: {obj['sentence']}")
    print(f"tokens: {obj['tokens']}")
    print(f"bio_tags: {obj['bio_tags']}")
    print("------------------------------------------------")

print("*"*100)
print("                                            DONE!")
print("*"*100)
# Out:
# Streaming output truncated to the last 5000 lines.
# ------------------------------------------------
# 28752. sentence: Rainy day run - need a {difficulty: extreme difficulty} {route_length: 4.5 kilometers} route with good pavement from {start_location: shlomo zalman shragai} {loca_start_num: 40}
# tokens: ['Rainy', 'day', 'run', '-', 'need', 'a', 'extreme', 'difficulty', '4.5', 'kilometers', 'route', 'with', 'good', 'pavement', 'from', 'shlomo', 'zalman', 'shragai', '40']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'O', 'B-difficulty', 'I-difficulty', 'B-route_length', 'I-route_length', 'O', 'O', 'O', 'O', 'O', 'B-start_location', 'I-start_location', 'I-start_location', 'B-loca_start_num']
# ------------------------------------------------
# 28753. sentence: i want to run {route_length: 18.0 km} from {start_location: poland} to {end_location: yigael yadin street}
# tokens: ['i', 'want', 'to', 'run', '18.0', 'km', 'from', 'poland', 'to', 'yigael', 'yadin', 'street']
# bio_tags: ['O', 'O', 'O', 'O', 'B-route_length', 'I-route_length', 'O', 'B-start_location', 'O', 'B-end_location', 'I-end_location', 'I-end_location']
# ------------------------------------------------
# 28754. sentence: Plan a {difficulty: somewhat tough} run between {start_location: king solomon} {loca_start_num: 84} and {end_location: hayarkon} {loca_end_num: 39} for {route_length: 2 km}.
# tokens: ['Plan', 'a', 'somewhat', 'tough', 'run', 'between', 'king', 'solomon', '84', 'and', 'hayarkon', '39', 'for', '2', 'km', '.']
# bio_tags: ['O', 'O', 'B-difficulty', 'I-difficulty', 'O', 'O', 'B-start_location', 'I-start_location', 'B-loca_start_num', 'O', 'B-end_location', 'B-loca_end_num', 'O', 'B-route_length', 'I-route_length', 'O']
# ------------------------------------------------
# 28755. sentence: Map me a route from {start_location: hillel street} {loca_start_num: 28}
# tokens: ['Map', 'me', 'a', 'route', 'from', 'hillel', 'street', '28']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'B-start_location', 'I-start_location', 'B-loca_start_num']
# ------------------------------------------------
# 28756. sentence: experienced marathoner seeking {difficulty: medium} route {route_length: 10-15 km} beginning {start_location: israel prize street} {loca_start_num: 27} finishing {end_location: daniel kahneman} {loca_end_num: 5}
# tokens: ['experienced', 'marathoner', 'seeking', 'medium', 'route', '10-15', 'km', 'beginning', 'israel', 'prize', 'street', '27', 'finishing', 'daniel', 'kahneman', '5']
# bio_tags: ['O', 'O', 'O', 'B-difficulty', 'O', 'B-route_length', 'I-route_length', 'O', 'B-start_location', 'I-start_location', 'I-start_location', 'B-loca_start_num', 'O', 'B-end_location', 'I-end_location', 'B-loca_end_num']
# ------------------------------------------------
# 28757. sentence: first time in israel need {difficulty: challenging} path {route_length: very long} from {start_location: ein gedi} {loca_start_num: 59} 2 {end_location: hannah szenes street} {loca_end_num: 98}
# tokens: ['first', 'time', 'in', 'israel', 'need', 'challenging', 'path', 'very', 'long', 'from', 'ein', 'gedi', '59', '2', 'hannah', 'szenes', 'street', '98']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'B-difficulty', 'O', 'B-route_length', 'I-route_length', 'O', 'B-start_location', 'I-start_location', 'B-loca_start_num', 'O', 'B-end_location', 'I-end_location', 'I-end_location', 'B-loca_end_num']
# ------------------------------------------------
# 28758. sentence: Could you help me plan a {difficulty: flat and easy} route for my training? I live near {start_location: herzl} {loca_start_num: 39} and want to run about {route_length: 2 kilometers}
# tokens: ['Could', 'you', 'help', 'me', 'plan', 'a', 'flat', 'and', 'easy', 'route', 'for', 'my', 'training?', 'I', 'live', 'near', 'herzl', '39', 'and', 'want', 'to', 'run', 'about', '2', 'kilometers']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'O', 'B-difficulty', 'I-difficulty', 'I-difficulty', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-start_location', 'B-loca_start_num', 'O', 'O', 'O', 'O', 'O', 'B-route_length', 'I-route_length']
# ------------------------------------------------
# 28759. sentence: {start_location: jabotinsky} {loca_start_num: 7} to {end_location: cafe kassit} {loca_end_num: 1}, make it {difficulty: slightly challenging}
# tokens: ['jabotinsky', '7', 'to', 'cafe', 'kassit', '1', ',', 'make', 'it', 'slightly', 'challenging']
# bio_tags: ['B-start_location', 'B-loca_start_num', 'O', 'B-end_location', 'I-end_location', 'B-loca_end_num', 'O', 'O', 'O', 'B-difficulty', 'I-difficulty']
# ------------------------------------------------
# 28760. sentence: competitive runner need {difficulty: slightly challenging} track {route_length: 10.0 km} from {start_location: cameri} {loca_start_num: 42} to {end_location: ancient harbor} {loca_end_num: 45}
# tokens: ['competitive', 'runner', 'need', 'slightly', 'challenging', 'track', '10.0', 'km', 'from', 'cameri', '42', 'to', 'ancient', 'harbor', '45']
# bio_tags: ['O', 'O', 'O', 'B-difficulty', 'I-difficulty', 'O', 'B-route_length', 'I-route_length', 'O', 'B-start_location', 'B-loca_start_num', 'O', 'B-end_location', 'I-end_location', 'B-loca_end_num']
# ------------------------------------------------
# 28761. sentence: looking for {difficulty: very hard} running path {route_length: 4.0 km} from {start_location: templar street} {loca_start_num: 16} to {end_location: shlomzion hamalka} {loca_end_num: 56}
# tokens: ['looking', 'for', 'very', 'hard', 'running', 'path', '4.0', 'km', 'from', 'templar', 'street', '16', 'to', 'shlomzion', 'hamalka', '56']
# bio_tags: ['O', 'O', 'B-difficulty', 'I-difficulty', 'O', 'O', 'B-route_length', 'I-route_length', 'O', 'B-start_location', 'I-start_location', 'B-loca_start_num', 'O', 'B-end_location', 'I-end_location', 'B-loca_end_num']
# ------------------------------------------------
# 28762. sentence: where do people usually run here?
# tokens: ['where', 'do', 'people', 'usually', 'run', 'here?']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'O']
# ------------------------------------------------
# 28763. sentence: good path for morning run?
# tokens: ['good', 'path', 'for', 'morning', 'run?']
# bio_tags: ['O', 'O', 'O', 'O', 'O']
# ------------------------------------------------
# 28764. sentence: Training for a marathon from {start_location: silicon wadi street} {loca_start_num: 73}
# tokens: ['Training', 'for', 'a', 'marathon', 'from', 'silicon', 'wadi', 'street', '73']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'B-start_location', 'I-start_location', 'I-start_location', 'B-loca_start_num']
# ------------------------------------------------
# 28765. sentence: Planning a {route_length: 700 meters} {difficulty: intense} run from {start_location: tel dan street} {loca_start_num: 2} to {end_location: chaim weizmann} {loca_end_num: 23} - would love something with good morning light for photos
# tokens: ['Planning', 'a', '700', 'meters', 'intense', 'run', 'from', 'tel', 'dan', 'street', '2', 'to', 'chaim', 'weizmann', '23', '-', 'would', 'love', 'something', 'with', 'good', 'morning', 'light', 'for', 'photos']
# bio_tags: ['O', 'O', 'B-route_length', 'I-route_length', 'B-difficulty', 'O', 'O', 'B-start_location', 'I-start_location', 'I-start_location', 'B-loca_start_num', 'O', 'B-end_location', 'I-end_location', 'B-loca_end_num', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ------------------------------------------------
# 28766. sentence: want {difficulty: very hard} run {route_length: 7.0 km} starting point {start_location: port street} {loca_start_num: 30} endpoint {end_location: red sea} {loca_end_num: 93}
# tokens: ['want', 'very', 'hard', 'run', '7.0', 'km', 'starting', 'point', 'port', 'street', '30', 'endpoint', 'red', 'sea', '93']
# bio_tags: ['O', 'B-difficulty', 'I-difficulty', 'O', 'B-route_length', 'I-route_length', 'O', 'O', 'B-start_location', 'I-start_location', 'B-loca_start_num', 'O', 'B-end_location', 'I-end_location', 'B-loca_end_num']
# ------------------------------------------------
# 28767. sentence: staying near {start_location: isaiah} need running route
# tokens: ['staying', 'near', 'isaiah', 'need', 'running', 'route']
# bio_tags: ['O', 'O', 'B-start_location', 'O', 'O', 'O']
# ------------------------------------------------
# 28768. sentence: Need a sunset route around {route_length: 18.5 km} from {start_location: ari folman street} {loca_start_num: 27}
# tokens: ['Need', 'a', 'sunset', 'route', 'around', '18.5', 'km', 'from', 'ari', 'folman', 'street', '27']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'B-route_length', 'I-route_length', 'O', 'B-start_location', 'I-start_location', 'I-start_location', 'B-loca_start_num']
# ------------------------------------------------
# 28769. sentence: plan {route_length: 700 meters} route ending at {end_location: pierre koenig} {loca_end_num: 14}
# tokens: ['plan', '700', 'meters', 'route', 'ending', 'at', 'pierre', 'koenig', '14']
# bio_tags: ['O', 'B-route_length', 'I-route_length', 'O', 'O', 'O', 'B-end_location', 'I-end_location', 'B-loca_end_num']
# ------------------------------------------------
# 28770. sentence: Need a tempo run route - {difficulty: difficult but rewarding} {route_length: 17 kilometers} from {start_location: german colony street} {loca_start_num: 21}
# tokens: ['Need', 'a', 'tempo', 'run', 'route', '-', 'difficult', 'but', 'rewarding', '17', 'kilometers', 'from', 'german', 'colony', 'street', '21']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'O', 'B-difficulty', 'I-difficulty', 'I-difficulty', 'B-route_length', 'I-route_length', 'O', 'B-start_location', 'I-start_location', 'I-start_location', 'B-loca_start_num']
# ------------------------------------------------
# 28771. sentence: new to running need advice
# tokens: ['new', 'to', 'running', 'need', 'advice']
# bio_tags: ['O', 'O', 'O', 'O', 'O']
# ------------------------------------------------
# 28772. sentence: Hey there, I'm looking for a {difficulty: somewhat tough} running route that starts from {start_location: yefet} {loca_start_num: 14} and goes all the way to {end_location: hazaatar street} {loca_end_num: 31}, something around {route_length: 12.5 kilometers} would be perfect
# tokens: ['Hey', 'there,', "I'm", 'looking', 'for', 'a', 'somewhat', 'tough', 'running', 'route', 'that', 'starts', 'from', 'yefet', '14', 'and', 'goes', 'all', 'the', 'way', 'to', 'hazaatar', 'street', '31', ',', 'something', 'around', '12.5', 'kilometers', 'would', 'be', 'perfect']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'O', 'B-difficulty', 'I-difficulty', 'O', 'O', 'O', 'O', 'O', 'B-start_location', 'B-loca_start_num', 'O', 'O', 'O', 'O', 'O', 'O', 'B-end_location', 'I-end_location', 'B-loca_end_num', 'O', 'O', 'O', 'B-route_length', 'I-route_length', 'O', 'O', 'O']
# ------------------------------------------------
# 28773. sentence: help plan my first 5k route
# tokens: ['help', 'plan', 'my', 'first', '5k', 'route']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'O']
# ------------------------------------------------
# 28774. sentence: Meeting friends for a run - what's a good {route_length: 5.0 kilometers} route near {start_location: weizmann institute} {loca_start_num: 8}?
# tokens: ['Meeting', 'friends', 'for', 'a', 'run', '-', "what's", 'a', 'good', '5.0', 'kilometers', 'route', 'near', 'weizmann', 'institute', '8', '?']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-route_length', 'I-route_length', 'O', 'O', 'B-start_location', 'I-start_location', 'B-loca_start_num', 'O']
# ------------------------------------------------
# 28775. sentence: Looking to crush a {difficulty: not hard} {route_length: 500 meters} from {start_location: eilat street} {loca_start_num: 58} to {end_location: hagefen} {loca_end_num: 42}
# tokens: ['Looking', 'to', 'crush', 'a', 'not', 'hard', '500', 'meters', 'from', 'eilat', 'street', '58', 'to', 'hagefen', '42']
# bio_tags: ['O', 'O', 'O', 'O', 'B-difficulty', 'I-difficulty', 'B-route_length', 'I-route_length', 'O', 'B-start_location', 'I-start_location', 'B-loca_start_num', 'O', 'B-end_location', 'B-loca_end_num']
# ------------------------------------------------
# 28776. sentence: Got any decent {route_length: 9.5 km} loops starting from {start_location: reuven rubin street} {loca_start_num: 95}?
# tokens: ['Got', 'any', 'decent', '9.5', 'km', 'loops', 'starting', 'from', 'reuven', 'rubin', 'street', '95', '?']
# bio_tags: ['O', 'O', 'O', 'B-route_length', 'I-route_length', 'O', 'O', 'O', 'B-start_location', 'I-start_location', 'I-start_location', 'B-loca_start_num', 'O']
# ------------------------------------------------
# 28777. sentence: {start_location: yad harutzim street} {loca_start_num: 65} to {end_location: unity} {loca_end_num: 48}, not too difficult
# tokens: ['yad', 'harutzim', 'street', '65', 'to', 'unity', '48', ',', 'not', 'too', 'difficult']
# bio_tags: ['B-start_location', 'I-start_location', 'I-start_location', 'B-loca_start_num', 'O', 'B-end_location', 'B-loca_end_num', 'O', 'O', 'O', 'O']
# ------------------------------------------------
# 28778. sentence: help plan my morning exercise
# tokens: ['help', 'plan', 'my', 'morning', 'exercise']
# bio_tags: ['O', 'O', 'O', 'O', 'O']
# ------------------------------------------------
# 28779. sentence: start at {start_location: sheinkin street} going to beach
# tokens: ['start', 'at', 'sheinkin', 'street', 'going', 'to', 'beach']
# bio_tags: ['O', 'O', 'B-start_location', 'I-start_location', 'O', 'O', 'O']
# ------------------------------------------------
# 28780. sentence: tourist need {difficulty: difficult but rewarding} track {route_length: 7 kilometers} beginning {start_location: jaffa gate} {loca_start_num: 97} finishing {end_location: fashion week street} {loca_end_num: 30}
# tokens: ['tourist', 'need', 'difficult', 'but', 'rewarding', 'track', '7', 'kilometers', 'beginning', 'jaffa', 'gate', '97', 'finishing', 'fashion', 'week', 'street', '30']
# bio_tags: ['O', 'O', 'B-difficulty', 'I-difficulty', 'I-difficulty', 'O', 'B-route_length', 'I-route_length', 'O', 'B-start_location', 'I-start_location', 'B-loca_start_num', 'O', 'B-end_location', 'I-end_location', 'I-end_location', 'B-loca_end_num']
# ------------------------------------------------
# 28781. sentence: need route for evening run
# tokens: ['need', 'route', 'for', 'evening', 'run']
# bio_tags: ['O', 'O', 'O', 'O', 'O']
# ------------------------------------------------
# 28782. sentence: simple running path please
# tokens: ['simple', 'running', 'path', 'please']
# bio_tags: ['O', 'O', 'O', 'O']
# ------------------------------------------------
# 28783. sentence: Can you suggest a nice morning running path that's not too difficult? Maybe around {route_length: extremely long} somewhere near the beach?
# tokens: ['Can', 'you', 'suggest', 'a', 'nice', 'morning', 'running', 'path', "that's", 'not', 'too', 'difficult?', 'Maybe', 'around', 'extremely', 'long', 'somewhere', 'near', 'the', 'beach?']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-route_length', 'I-route_length', 'O', 'O', 'O', 'O']
# ------------------------------------------------
# 28784. sentence: It's hot today - got any shaded {route_length: moderate distance} routes from {start_location: naomi shemer street} {loca_start_num: 72}?
# tokens: ["It's", 'hot', 'today', '-', 'got', 'any', 'shaded', 'moderate', 'distance', 'routes', 'from', 'naomi', 'shemer', 'street', '72', '?']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-route_length', 'I-route_length', 'O', 'O', 'B-start_location', 'I-start_location', 'I-start_location', 'B-loca_start_num', 'O']
# ------------------------------------------------
# 28785. sentence: advanced athlete want {difficulty: somewhat tough} route {route_length: 14 km} from {start_location: dan street} {loca_start_num: 80} to {end_location: uri zvi greenberg street} {loca_end_num: 48}
# tokens: ['advanced', 'athlete', 'want', 'somewhat', 'tough', 'route', '14', 'km', 'from', 'dan', 'street', '80', 'to', 'uri', 'zvi', 'greenberg', 'street', '48']
# bio_tags: ['O', 'O', 'O', 'B-difficulty', 'I-difficulty', 'O', 'B-route_length', 'I-route_length', 'O', 'B-start_location', 'I-start_location', 'B-loca_start_num', 'O', 'B-end_location', 'I-end_location', 'I-end_location', 'I-end_location', 'B-loca_end_num']
# ------------------------------------------------
# 28786. sentence: pls make running route {difficulty: easy} about {route_length: 600 meters} starting {start_location: kurdistan street} {loca_start_num: 48} ending {end_location: hanegev street} {loca_end_num: 86}
# tokens: ['pls', 'make', 'running', 'route', 'easy', 'about', '600', 'meters', 'starting', 'kurdistan', 'street', '48', 'ending', 'hanegev', 'street', '86']
# bio_tags: ['O', 'O', 'O', 'O', 'B-difficulty', 'O', 'B-route_length', 'I-route_length', 'O', 'B-start_location', 'I-start_location', 'B-loca_start_num', 'O', 'B-end_location', 'I-end_location', 'B-loca_end_num']
# ------------------------------------------------
# 28787. sentence: Plan a route of {route_length: under 1 km}.
# tokens: ['Plan', 'a', 'route', 'of', 'under', '1', 'km', '.']
# bio_tags: ['O', 'O', 'O', 'O', 'B-route_length', 'I-route_length', 'I-route_length', 'O']
# ------------------------------------------------
# 28788. sentence: Hey, I wanna do a {route_length: 4.0 kilometers} run from {start_location: hazaatar} {loca_start_num: 56}, any good routes?
# tokens: ['Hey,', 'I', 'wanna', 'do', 'a', '4.0', 'kilometers', 'run', 'from', 'hazaatar', '56', ',', 'any', 'good', 'routes?']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'B-route_length', 'I-route_length', 'O', 'O', 'B-start_location', 'B-loca_start_num', 'O', 'O', 'O', 'O']
# ------------------------------------------------
# 28789. sentence: First-time runner here looking for a beginner-friendly route without too many hills - maybe starting from {start_location: cameri street} and heading towards the beach area?
# tokens: ['First-time', 'runner', 'here', 'looking', 'for', 'a', 'beginner-friendly', 'route', 'without', 'too', 'many', 'hills', '-', 'maybe', 'starting', 'from', 'cameri', 'street', 'and', 'heading', 'towards', 'the', 'beach', 'area?']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-start_location', 'I-start_location', 'O', 'O', 'O', 'O', 'O', 'O']
# ------------------------------------------------
# 28790. sentence: Show me some routes near {end_location: king solomon street} {loca_end_num: 40}
# tokens: ['Show', 'me', 'some', 'routes', 'near', 'king', 'solomon', 'street', '40']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'B-end_location', 'I-end_location', 'I-end_location', 'B-loca_end_num']
# ------------------------------------------------
# 28791. sentence: first time runner here, any suggestions?
# tokens: ['first', 'time', 'runner', 'here,', 'any', 'suggestions?']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'O']
# ------------------------------------------------
# 28792. sentence: I want a {difficulty: not hard} route to {end_location: malkhei yisrael} {loca_end_num: 33}.
# tokens: ['I', 'want', 'a', 'not', 'hard', 'route', 'to', 'malkhei', 'yisrael', '33', '.']
# bio_tags: ['O', 'O', 'O', 'B-difficulty', 'I-difficulty', 'O', 'O', 'B-end_location', 'I-end_location', 'B-loca_end_num', 'O']
# ------------------------------------------------
# 28793. sentence: I need a running route that goes from {start_location: shazar} {loca_start_num: 34} to {end_location: maskit} {loca_end_num: 10}.
# tokens: ['I', 'need', 'a', 'running', 'route', 'that', 'goes', 'from', 'shazar', '34', 'to', 'maskit', '10', '.']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-start_location', 'B-loca_start_num', 'O', 'B-end_location', 'B-loca_end_num', 'O']
# ------------------------------------------------
# 28794. sentence: Where should I run today?
# tokens: ['Where', 'should', 'I', 'run', 'today?']
# bio_tags: ['O', 'O', 'O', 'O', 'O']
# ------------------------------------------------
# 28795. sentence: elderly person looking for nice walking route
# tokens: ['elderly', 'person', 'looking', 'for', 'nice', 'walking', 'route']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O']
# ------------------------------------------------
# 28796. sentence: Running with my dog from {start_location: schocken street} {loca_start_num: 33}
# tokens: ['Running', 'with', 'my', 'dog', 'from', 'schocken', 'street', '33']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'B-start_location', 'I-start_location', 'B-loca_start_num']
# ------------------------------------------------
# 28797. sentence: Yo, need a {route_length: 4.0 km} route near {start_location: yigael yadin} {loca_start_num: 80}
# tokens: ['Yo,', 'need', 'a', '4.0', 'km', 'route', 'near', 'yigael', 'yadin', '80']
# bio_tags: ['O', 'O', 'O', 'B-route_length', 'I-route_length', 'O', 'O', 'B-start_location', 'I-start_location', 'B-loca_start_num']
# ------------------------------------------------
# 28798. sentence: Planning a social run - need a {difficulty: medium} {route_length: 14.0 km} route with good stopping points
# tokens: ['Planning', 'a', 'social', 'run', '-', 'need', 'a', 'medium', '14.0', 'km', 'route', 'with', 'good', 'stopping', 'points']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-difficulty', 'B-route_length', 'I-route_length', 'O', 'O', 'O', 'O', 'O']
# ------------------------------------------------
# 28799. sentence: {start_location: where i am} {loca_start_num: 67} to {end_location: kiryat yovel street} {loca_end_num: 94}, {difficulty: moderate effort} {route_length: short sprint} please
# tokens: ['where', 'i', 'am', '67', 'to', 'kiryat', 'yovel', 'street', '94', ',', 'moderate', 'effort', 'short', 'sprint', 'please']
# bio_tags: ['B-start_location', 'I-start_location', 'I-start_location', 'B-loca_start_num', 'O', 'B-end_location', 'I-end_location', 'I-end_location', 'B-loca_end_num', 'O', 'B-difficulty', 'I-difficulty', 'B-route_length', 'I-route_length', 'O']
# ------------------------------------------------
# 28800. sentence: {start_location: rambam street} {loca_start_num: 62} to {end_location: daniel} {loca_end_num: 2}, {difficulty: extreme difficulty} {route_length: 20.0 kilometers}
# tokens: ['rambam', 'street', '62', 'to', 'daniel', '2', ',', 'extreme', 'difficulty', '20.0', 'kilometers']
# bio_tags: ['B-start_location', 'I-start_location', 'B-loca_start_num', 'O', 'B-end_location', 'B-loca_end_num', 'O', 'B-difficulty', 'I-difficulty', 'B-route_length', 'I-route_length']
# ------------------------------------------------
# 28801. sentence: looking for {difficulty: challenging} running path {route_length: 9.0 kilometers} from {start_location: bethlehem road} {loca_start_num: 47} to {end_location: sharon street} {loca_end_num: 86}
# tokens: ['looking', 'for', 'challenging', 'running', 'path', '9.0', 'kilometers', 'from', 'bethlehem', 'road', '47', 'to', 'sharon', 'street', '86']
# bio_tags: ['O', 'O', 'B-difficulty', 'O', 'O', 'B-route_length', 'I-route_length', 'O', 'B-start_location', 'I-start_location', 'B-loca_start_num', 'O', 'B-end_location', 'I-end_location', 'B-loca_end_num']
# ------------------------------------------------
# 28802. sentence: hi can u make me a {difficulty: intense} route?
# tokens: ['hi', 'can', 'u', 'make', 'me', 'a', 'intense', 'route?']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'O', 'B-difficulty', 'O']
# ------------------------------------------------
# 28803. sentence: Gimme a {difficulty: very hard} route around {route_length: 9 kilometers} near {start_location: ari folman street} {loca_start_num: 26}
# tokens: ['Gimme', 'a', 'very', 'hard', 'route', 'around', '9', 'kilometers', 'near', 'ari', 'folman', 'street', '26']
# bio_tags: ['O', 'O', 'B-difficulty', 'I-difficulty', 'O', 'O', 'B-route_length', 'I-route_length', 'O', 'B-start_location', 'I-start_location', 'I-start_location', 'B-loca_start_num']
# ------------------------------------------------
# 28804. sentence: elderly person looking for nice walking route
# tokens: ['elderly', 'person', 'looking', 'for', 'nice', 'walking', 'route']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O']
# ------------------------------------------------
# 28805. sentence: Hi! I've been running for years and need a {difficulty: very easy} training route that's about {route_length: 5.0 kilometers}, starting from my apartment on {start_location: bukhara}
# tokens: ['Hi!', "I've", 'been', 'running', 'for', 'years', 'and', 'need', 'a', 'very', 'easy', 'training', 'route', "that's", 'about', '5.0', 'kilometers', ',', 'starting', 'from', 'my', 'apartment', 'on', 'bukhara']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-difficulty', 'I-difficulty', 'O', 'O', 'O', 'O', 'B-route_length', 'I-route_length', 'O', 'O', 'O', 'O', 'O', 'O', 'B-start_location']
# ------------------------------------------------
# 28806. sentence: Looking for a running route that passes by some good breakfast spots - starting from {start_location: haayala street} {loca_start_num: 13} and heading towards {end_location: palmach street} {loca_end_num: 6}
# tokens: ['Looking', 'for', 'a', 'running', 'route', 'that', 'passes', 'by', 'some', 'good', 'breakfast', 'spots', '-', 'starting', 'from', 'haayala', 'street', '13', 'and', 'heading', 'towards', 'palmach', 'street', '6']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-start_location', 'I-start_location', 'B-loca_start_num', 'O', 'O', 'O', 'B-end_location', 'I-end_location', 'B-loca_end_num']
# ------------------------------------------------
# 28807. sentence: running track suggestions?
# tokens: ['running', 'track', 'suggestions?']
# bio_tags: ['O', 'O', 'O']
# ------------------------------------------------
# 28808. sentence: I'm visiting from America for a week and staying near {start_location: hora} - would love suggestions for a morning running route with good views of the city
# tokens: ["I'm", 'visiting', 'from', 'America', 'for', 'a', 'week', 'and', 'staying', 'near', 'hora', '-', 'would', 'love', 'suggestions', 'for', 'a', 'morning', 'running', 'route', 'with', 'good', 'views', 'of', 'the', 'city']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-start_location', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ------------------------------------------------
# 28809. sentence: Coach says {route_length: 14.0 km} {difficulty: somewhat tough} run, got anything from {start_location: eliyahu hanavi street} {loca_start_num: 84}?
# tokens: ['Coach', 'says', '14.0', 'km', 'somewhat', 'tough', 'run,', 'got', 'anything', 'from', 'eliyahu', 'hanavi', 'street', '84', '?']
# bio_tags: ['O', 'O', 'B-route_length', 'I-route_length', 'B-difficulty', 'I-difficulty', 'O', 'O', 'O', 'O', 'B-start_location', 'I-start_location', 'I-start_location', 'B-loca_start_num', 'O']
# ------------------------------------------------
# 28810. sentence: {route_length: 20 km} {difficulty: difficult but rewarding} track starting {start_location: strauss} {loca_start_num: 89}
# tokens: ['20', 'km', 'difficult', 'but', 'rewarding', 'track', 'starting', 'strauss', '89']
# bio_tags: ['B-route_length', 'I-route_length', 'B-difficulty', 'I-difficulty', 'I-difficulty', 'O', 'O', 'B-start_location', 'B-loca_start_num']
# ------------------------------------------------
# 28811. sentence: I'm visiting from America for a week and staying near {start_location: templar street} - would love suggestions for a morning running route with good views of the city
# tokens: ["I'm", 'visiting', 'from', 'America', 'for', 'a', 'week', 'and', 'staying', 'near', 'templar', 'street', '-', 'would', 'love', 'suggestions', 'for', 'a', 'morning', 'running', 'route', 'with', 'good', 'views', 'of', 'the', 'city']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-start_location', 'I-start_location', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ------------------------------------------------
# 28812. sentence: Want a flat route from {start_location: gottex} {loca_start_num: 32}
# tokens: ['Want', 'a', 'flat', 'route', 'from', 'gottex', '32']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'B-start_location', 'B-loca_start_num']
# ------------------------------------------------
# 28813. sentence: help me plan my run
# tokens: ['help', 'me', 'plan', 'my', 'run']
# bio_tags: ['O', 'O', 'O', 'O', 'O']
# ------------------------------------------------
# 28814. sentence: I'm looking for a {difficulty: moderate effort} run starting from {start_location: nordau boulevard} {loca_start_num: 36} to {end_location: yehuda street} {loca_end_num: 13}, covering {route_length: 14.0 kilometers}.
# tokens: ["I'm", 'looking', 'for', 'a', 'moderate', 'effort', 'run', 'starting', 'from', 'nordau', 'boulevard', '36', 'to', 'yehuda', 'street', '13', ',', 'covering', '14.0', 'kilometers', '.']
# bio_tags: ['O', 'O', 'O', 'O', 'B-difficulty', 'I-difficulty', 'O', 'O', 'O', 'B-start_location', 'I-start_location', 'B-loca_start_num', 'O', 'B-end_location', 'I-end_location', 'B-loca_end_num', 'O', 'O', 'B-route_length', 'I-route_length', 'O']
# ------------------------------------------------
# 28815. sentence: first time runner here need {difficulty: slightly challenging} track {route_length: 20.0 km} from {start_location: jaffa street} {loca_start_num: 3} 2 {end_location: fashion week street} {loca_end_num: 32}
# tokens: ['first', 'time', 'runner', 'here', 'need', 'slightly', 'challenging', 'track', '20.0', 'km', 'from', 'jaffa', 'street', '3', '2', 'fashion', 'week', 'street', '32']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'B-difficulty', 'I-difficulty', 'O', 'B-route_length', 'I-route_length', 'O', 'B-start_location', 'I-start_location', 'B-loca_start_num', 'O', 'B-end_location', 'I-end_location', 'I-end_location', 'B-loca_end_num']
# ------------------------------------------------
# 28816. sentence: route planning help please
# tokens: ['route', 'planning', 'help', 'please']
# bio_tags: ['O', 'O', 'O', 'O']
# ------------------------------------------------
# 28817. sentence: Need a pre work route around {route_length: 12.5 kilometers} starting at {start_location: accelerator} {loca_start_num: 100}
# tokens: ['Need', 'a', 'pre', 'work', 'route', 'around', '12.5', 'kilometers', 'starting', 'at', 'accelerator', '100']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'O', 'B-route_length', 'I-route_length', 'O', 'O', 'B-start_location', 'B-loca_start_num']
# ------------------------------------------------
# 28818. sentence: start from {start_location: my exact location} to {end_location: yissachar street}
# tokens: ['start', 'from', 'my', 'exact', 'location', 'to', 'yissachar', 'street']
# bio_tags: ['O', 'O', 'B-start_location', 'I-start_location', 'I-start_location', 'O', 'B-end_location', 'I-end_location']
# ------------------------------------------------
# 28819. sentence: start from {start_location: shmuel hanagid street} {loca_start_num: 94} to {end_location: dan shechtman street}
# tokens: ['start', 'from', 'shmuel', 'hanagid', 'street', '94', 'to', 'dan', 'shechtman', 'street']
# bio_tags: ['O', 'O', 'B-start_location', 'I-start_location', 'I-start_location', 'B-loca_start_num', 'O', 'B-end_location', 'I-end_location', 'I-end_location']
# ------------------------------------------------
# 28820. sentence: Looking for a route with coffee shops along the way, around {route_length: 11.0 kilometers}
# tokens: ['Looking', 'for', 'a', 'route', 'with', 'coffee', 'shops', 'along', 'the', 'way,', 'around', '11.0', 'kilometers']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-route_length', 'I-route_length']
# ------------------------------------------------
# 28821. sentence: I need a running route that goes from {start_location: arthur ruppin street} {loca_start_num: 53} to {end_location: ashkelon street} {loca_end_num: 51}.
# tokens: ['I', 'need', 'a', 'running', 'route', 'that', 'goes', 'from', 'arthur', 'ruppin', 'street', '53', 'to', 'ashkelon', 'street', '51', '.']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-start_location', 'I-start_location', 'I-start_location', 'B-loca_start_num', 'O', 'B-end_location', 'I-end_location', 'B-loca_end_num', 'O']
# ------------------------------------------------
# 28822. sentence: need a route for tomorrow
# tokens: ['need', 'a', 'route', 'for', 'tomorrow']
# bio_tags: ['O', 'O', 'O', 'O', 'O']
# ------------------------------------------------
# 28823. sentence: make me {difficulty: hard} path
# tokens: ['make', 'me', 'hard', 'path']
# bio_tags: ['O', 'O', 'B-difficulty', 'O']
# ------------------------------------------------
# 28824. sentence: Where should I run today?
# tokens: ['Where', 'should', 'I', 'run', 'today?']
# bio_tags: ['O', 'O', 'O', 'O', 'O']
# ------------------------------------------------
# 28825. sentence: My usual route is boring, need a {difficulty: difficult but rewarding} {route_length: 16.5 kilometers} alternative from {start_location: gilboa street} {loca_start_num: 73}
# tokens: ['My', 'usual', 'route', 'is', 'boring,', 'need', 'a', 'difficult', 'but', 'rewarding', '16.5', 'kilometers', 'alternative', 'from', 'gilboa', 'street', '73']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-difficulty', 'I-difficulty', 'I-difficulty', 'B-route_length', 'I-route_length', 'O', 'O', 'B-start_location', 'I-start_location', 'B-loca_start_num']
# ------------------------------------------------
# 28826. sentence: where should i start my run?
# tokens: ['where', 'should', 'i', 'start', 'my', 'run?']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'O']
# ------------------------------------------------
# 28827. sentence: Got my headphones charged, ready for a {route_length: 2 kilometers} run from {start_location: rafael eitan} {loca_start_num: 4}
# tokens: ['Got', 'my', 'headphones', 'charged,', 'ready', 'for', 'a', '2', 'kilometers', 'run', 'from', 'rafael', 'eitan', '4']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-route_length', 'I-route_length', 'O', 'O', 'B-start_location', 'I-start_location', 'B-loca_start_num']
# ------------------------------------------------
# 28828. sentence: Want to run past {end_location: my coordinates}, maybe {route_length: 9 km} total?
# tokens: ['Want', 'to', 'run', 'past', 'my', 'coordinates', ',', 'maybe', '9', 'km', 'total?']
# bio_tags: ['O', 'O', 'O', 'O', 'B-end_location', 'I-end_location', 'O', 'O', 'B-route_length', 'I-route_length', 'O']
# ------------------------------------------------
# 28829. sentence: I want a {difficulty: intense} route to {end_location: neve tzedek} {loca_end_num: 57}.
# tokens: ['I', 'want', 'a', 'intense', 'route', 'to', 'neve', 'tzedek', '57', '.']
# bio_tags: ['O', 'O', 'O', 'B-difficulty', 'O', 'O', 'B-end_location', 'I-end_location', 'B-loca_end_num', 'O']
# ------------------------------------------------
# 28830. sentence: start {start_location: ofek street} {loca_start_num: 49} {difficulty: somewhat tough}
# tokens: ['start', 'ofek', 'street', '49', 'somewhat', 'tough']
# bio_tags: ['O', 'B-start_location', 'I-start_location', 'B-loca_start_num', 'B-difficulty', 'I-difficulty']
# ------------------------------------------------
# 28831. sentence: first time runner here, any suggestions?
# tokens: ['first', 'time', 'runner', 'here,', 'any', 'suggestions?']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'O']
# ------------------------------------------------
# 28832. sentence: {start_location: gaza road} {loca_start_num: 84} to {end_location: beit she'an street} {loca_end_num: 39}, make it {difficulty: not hard}
# tokens: ['gaza', 'road', '84', 'to', 'beit', "she'an", 'street', '39', ',', 'make', 'it', 'not', 'hard']
# bio_tags: ['B-start_location', 'I-start_location', 'B-loca_start_num', 'O', 'B-end_location', 'I-end_location', 'I-end_location', 'B-loca_end_num', 'O', 'O', 'O', 'B-difficulty', 'I-difficulty']
# ------------------------------------------------
# 28833. sentence: new to running need advice
# tokens: ['new', 'to', 'running', 'need', 'advice']
# bio_tags: ['O', 'O', 'O', 'O', 'O']
# ------------------------------------------------
# 28834. sentence: to {end_location: kinneret} {loca_end_num: 54} please
# tokens: ['to', 'kinneret', '54', 'please']
# bio_tags: ['O', 'B-end_location', 'B-loca_end_num', 'O']
# ------------------------------------------------
# 28835. sentence: need {difficulty: extreme difficulty} route about {route_length: 14 km}
# tokens: ['need', 'extreme', 'difficulty', 'route', 'about', '14', 'km']
# bio_tags: ['O', 'B-difficulty', 'I-difficulty', 'O', 'O', 'B-route_length', 'I-route_length']
# ------------------------------------------------
# 28836. sentence: Running with newbies, need an easy {route_length: 250 meters} loop from {start_location: yehuda leib pinsker street} {loca_start_num: 71}
# tokens: ['Running', 'with', 'newbies,', 'need', 'an', 'easy', '250', 'meters', 'loop', 'from', 'yehuda', 'leib', 'pinsker', 'street', '71']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'O', 'B-route_length', 'I-route_length', 'O', 'O', 'B-start_location', 'I-start_location', 'I-start_location', 'I-start_location', 'B-loca_start_num']
# ------------------------------------------------
# 28837. sentence: Map me a route from {start_location: acre} {loca_start_num: 40}
# tokens: ['Map', 'me', 'a', 'route', 'from', 'acre', '40']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'B-start_location', 'B-loca_start_num']
# ------------------------------------------------
# 28838. sentence: planning 5k where should i go
# tokens: ['planning', '5k', 'where', 'should', 'i', 'go']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'O']
# ------------------------------------------------
# 28839. sentence: run starting {start_location: david elazar street} {loca_start_num: 52}
# tokens: ['run', 'starting', 'david', 'elazar', 'street', '52']
# bio_tags: ['O', 'O', 'B-start_location', 'I-start_location', 'I-start_location', 'B-loca_start_num']
# ------------------------------------------------
# 28840. sentence: Need a sunset route around {route_length: 19.5 kilometers} from {start_location: nahalat binyamin street} {loca_start_num: 35}
# tokens: ['Need', 'a', 'sunset', 'route', 'around', '19.5', 'kilometers', 'from', 'nahalat', 'binyamin', 'street', '35']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'B-route_length', 'I-route_length', 'O', 'B-start_location', 'I-start_location', 'I-start_location', 'B-loca_start_num']
# ------------------------------------------------
# 28841. sentence: Need a shaded route from {start_location: new gate} {loca_start_num: 93}
# tokens: ['Need', 'a', 'shaded', 'route', 'from', 'new', 'gate', '93']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'B-start_location', 'I-start_location', 'B-loca_start_num']
# ------------------------------------------------
# 28842. sentence: Morning run starting at {start_location: nahal taninim street} {loca_start_num: 1}
# tokens: ['Morning', 'run', 'starting', 'at', 'nahal', 'taninim', 'street', '1']
# bio_tags: ['O', 'O', 'O', 'O', 'B-start_location', 'I-start_location', 'I-start_location', 'B-loca_start_num']
# ------------------------------------------------
# 28843. sentence: I want a {difficulty: somewhat tough} route from {start_location: deborah street} {loca_start_num: 56}.
# tokens: ['I', 'want', 'a', 'somewhat', 'tough', 'route', 'from', 'deborah', 'street', '56', '.']
# bio_tags: ['O', 'O', 'O', 'B-difficulty', 'I-difficulty', 'O', 'O', 'B-start_location', 'I-start_location', 'B-loca_start_num', 'O']
# ------------------------------------------------
# 28844. sentence: Need a pre work route around {route_length: 12.0 km} starting at {start_location: poland} {loca_start_num: 10}
# tokens: ['Need', 'a', 'pre', 'work', 'route', 'around', '12.0', 'km', 'starting', 'at', 'poland', '10']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'O', 'B-route_length', 'I-route_length', 'O', 'O', 'B-start_location', 'B-loca_start_num']
# ------------------------------------------------
# 28845. sentence: Hi there, I'm training for a half marathon and need a {difficulty: intense} route about {route_length: 16 kilometers}, preferably near the beach
# tokens: ['Hi', 'there,', "I'm", 'training', 'for', 'a', 'half', 'marathon', 'and', 'need', 'a', 'intense', 'route', 'about', '16', 'kilometers', ',', 'preferably', 'near', 'the', 'beach']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-difficulty', 'O', 'O', 'B-route_length', 'I-route_length', 'O', 'O', 'O', 'O', 'O']
# ------------------------------------------------
# 28846. sentence: Can you create a route from {start_location: revival street} {loca_start_num: 32} to {end_location: shavuot} {loca_end_num: 37}?
# tokens: ['Can', 'you', 'create', 'a', 'route', 'from', 'revival', 'street', '32', 'to', 'shavuot', '37', '?']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'O', 'B-start_location', 'I-start_location', 'B-loca_start_num', 'O', 'B-end_location', 'B-loca_end_num', 'O']
# ------------------------------------------------
# 28847. sentence: {start_location: pierre koenig} {loca_start_num: 15} to {end_location: yitzhak sadeh street} {loca_end_num: 68}, {route_length: 14 kilometers} please
# tokens: ['pierre', 'koenig', '15', 'to', 'yitzhak', 'sadeh', 'street', '68', ',', '14', 'kilometers', 'please']
# bio_tags: ['B-start_location', 'I-start_location', 'B-loca_start_num', 'O', 'B-end_location', 'I-end_location', 'I-end_location', 'B-loca_end_num', 'O', 'B-route_length', 'I-route_length', 'O']
# ------------------------------------------------
# 28848. sentence: Drop me a {difficulty: medium} route from {start_location: maariv} {loca_start_num: 83}
# tokens: ['Drop', 'me', 'a', 'medium', 'route', 'from', 'maariv', '83']
# bio_tags: ['O', 'O', 'O', 'B-difficulty', 'O', 'O', 'B-start_location', 'B-loca_start_num']
# ------------------------------------------------
# 28849. sentence: training for marathon need long route
# tokens: ['training', 'for', 'marathon', 'need', 'long', 'route']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'O']
# ------------------------------------------------
# 28850. sentence: {start_location: marcel janco street} {loca_start_num: 85} to {end_location: meah shearim} {loca_end_num: 32}, {difficulty: difficult but rewarding} please
# tokens: ['marcel', 'janco', 'street', '85', 'to', 'meah', 'shearim', '32', ',', 'difficult', 'but', 'rewarding', 'please']
# bio_tags: ['B-start_location', 'I-start_location', 'I-start_location', 'B-loca_start_num', 'O', 'B-end_location', 'I-end_location', 'B-loca_end_num', 'O', 'B-difficulty', 'I-difficulty', 'I-difficulty', 'O']
# ------------------------------------------------
# 28851. sentence: where can i do {route_length: 7 kilometers} run?
# tokens: ['where', 'can', 'i', 'do', '7', 'kilometers', 'run?']
# bio_tags: ['O', 'O', 'O', 'O', 'B-route_length', 'I-route_length', 'O']
# ------------------------------------------------
# 28852. sentence: can you recommend nice running spots?
# tokens: ['can', 'you', 'recommend', 'nice', 'running', 'spots?']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'O']
# ------------------------------------------------
# 28853. sentence: Training for a marathon from {start_location: agripas} {loca_start_num: 82}
# tokens: ['Training', 'for', 'a', 'marathon', 'from', 'agripas', '82']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'B-start_location', 'B-loca_start_num']
# ------------------------------------------------
# 28854. sentence: Crew run day, need a {route_length: quick run} route with photo ops near {start_location: bar ilan} {loca_start_num: 44}
# tokens: ['Crew', 'run', 'day,', 'need', 'a', 'quick', 'run', 'route', 'with', 'photo', 'ops', 'near', 'bar', 'ilan', '44']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'B-route_length', 'I-route_length', 'O', 'O', 'O', 'O', 'O', 'B-start_location', 'I-start_location', 'B-loca_start_num']
# ------------------------------------------------
# 28855. sentence: Can anyone recommend a good running path for a tourist? Staying in a hotel on {start_location: this place} and want to explore the city
# tokens: ['Can', 'anyone', 'recommend', 'a', 'good', 'running', 'path', 'for', 'a', 'tourist?', 'Staying', 'in', 'a', 'hotel', 'on', 'this', 'place', 'and', 'want', 'to', 'explore', 'the', 'city']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-start_location', 'I-start_location', 'O', 'O', 'O', 'O', 'O', 'O']
# ------------------------------------------------
# 28856. sentence: make me something challenging please
# tokens: ['make', 'me', 'something', 'challenging', 'please']
# bio_tags: ['O', 'O', 'O', 'O', 'O']
# ------------------------------------------------
# 28857. sentence: I need a {difficulty: difficult but rewarding} route of {route_length: 5-10 km}.
# tokens: ['I', 'need', 'a', 'difficult', 'but', 'rewarding', 'route', 'of', '5-10', 'km', '.']
# bio_tags: ['O', 'O', 'O', 'B-difficulty', 'I-difficulty', 'I-difficulty', 'O', 'O', 'B-route_length', 'I-route_length', 'O']
# ------------------------------------------------
# 28858. sentence: Midnight runner here, safe {route_length: very long} route from {start_location: gottex} {loca_start_num: 59}?
# tokens: ['Midnight', 'runner', 'here,', 'safe', 'very', 'long', 'route', 'from', 'gottex', '59', '?']
# bio_tags: ['O', 'O', 'O', 'O', 'B-route_length', 'I-route_length', 'O', 'O', 'B-start_location', 'B-loca_start_num', 'O']
# ------------------------------------------------
# 28859. sentence: where to run {route_length: 5-10 km}?
# tokens: ['where', 'to', 'run', '5-10', 'km', '?']
# bio_tags: ['O', 'O', 'O', 'B-route_length', 'I-route_length', 'O']
# ------------------------------------------------
# 28860. sentence: i want to run {route_length: 250 meters} from {start_location: ramon crater} to {end_location: zalman shneur street}
# tokens: ['i', 'want', 'to', 'run', '250', 'meters', 'from', 'ramon', 'crater', 'to', 'zalman', 'shneur', 'street']
# bio_tags: ['O', 'O', 'O', 'O', 'B-route_length', 'I-route_length', 'O', 'B-start_location', 'I-start_location', 'O', 'B-end_location', 'I-end_location', 'I-end_location']
# ------------------------------------------------
# 28861. sentence: newbie here want {difficulty: flat and easy} route {route_length: half-marathon length} start {start_location: jaffa street} {loca_start_num: 65} end {end_location: malchei israel} {loca_end_num: 60}
# tokens: ['newbie', 'here', 'want', 'flat', 'and', 'easy', 'route', 'half-marathon', 'length', 'start', 'jaffa', 'street', '65', 'end', 'malchei', 'israel', '60']
# bio_tags: ['O', 'O', 'O', 'B-difficulty', 'I-difficulty', 'I-difficulty', 'O', 'B-route_length', 'I-route_length', 'O', 'B-start_location', 'I-start_location', 'B-loca_start_num', 'O', 'B-end_location', 'I-end_location', 'B-loca_end_num']
# ------------------------------------------------
# 28862. sentence: Find me somewhere to run {route_length: 19.5 km}
# tokens: ['Find', 'me', 'somewhere', 'to', 'run', '19.5', 'km']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'B-route_length', 'I-route_length']
# ------------------------------------------------
# 28863. sentence: Looking for a {route_length: 16.5 kilometers} path from {start_location: stef wertheimer} {loca_start_num: 63} to {end_location: tiberias street} {loca_end_num: 56}, something not too challenging for my morning exercise
# tokens: ['Looking', 'for', 'a', '16.5', 'kilometers', 'path', 'from', 'stef', 'wertheimer', '63', 'to', 'tiberias', 'street', '56', ',', 'something', 'not', 'too', 'challenging', 'for', 'my', 'morning', 'exercise']
# bio_tags: ['O', 'O', 'O', 'B-route_length', 'I-route_length', 'O', 'O', 'B-start_location', 'I-start_location', 'B-loca_start_num', 'O', 'B-end_location', 'I-end_location', 'B-loca_end_num', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ------------------------------------------------
# 28864. sentence: i want to run {route_length: 8 km} from {start_location: oasis} to {end_location: bedouin path}
# tokens: ['i', 'want', 'to', 'run', '8', 'km', 'from', 'oasis', 'to', 'bedouin', 'path']
# bio_tags: ['O', 'O', 'O', 'O', 'B-route_length', 'I-route_length', 'O', 'B-start_location', 'O', 'B-end_location', 'I-end_location']
# ------------------------------------------------
# 28865. sentence: Building endurance, show me a {difficulty: extreme difficulty} {route_length: 1 km} route starting {start_location: shlomo zalman shragai street} {loca_start_num: 36}
# tokens: ['Building', 'endurance,', 'show', 'me', 'a', 'extreme', 'difficulty', '1', 'km', 'route', 'starting', 'shlomo', 'zalman', 'shragai', 'street', '36']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'B-difficulty', 'I-difficulty', 'B-route_length', 'I-route_length', 'O', 'O', 'B-start_location', 'I-start_location', 'I-start_location', 'I-start_location', 'B-loca_start_num']
# ------------------------------------------------
# ...
# tokens: ['elderly', 'person', 'need', 'very', 'hard', 'path', 'over', '20', 'km', 'start', 'old', 'city', 'market', '70', 'end', 'arlozorov', 'street', '36']
# bio_tags: ['O', 'O', 'O', 'B-difficulty', 'I-difficulty', 'O', 'B-route_length', 'I-route_length', 'I-route_length', 'O', 'B-start_location', 'I-start_location', 'I-start_location', 'B-loca_start_num', 'O', 'B-end_location', 'I-end_location', 'B-loca_end_num']
# ------------------------------------------------
# 29962. sentence: Map me a route from {start_location: yissachar street} {loca_start_num: 68}
# tokens: ['Map', 'me', 'a', 'route', 'from', 'yissachar', 'street', '68']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'B-start_location', 'I-start_location', 'B-loca_start_num']
# ------------------------------------------------
# 29963. sentence: can u plan my morning jog?
# tokens: ['can', 'u', 'plan', 'my', 'morning', 'jog?']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'O']
# ------------------------------------------------
# 29964. sentence: Long run Sunday starting at {start_location: kiryat yovel street} {loca_start_num: 99}
# tokens: ['Long', 'run', 'Sunday', 'starting', 'at', 'kiryat', 'yovel', 'street', '99']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'B-start_location', 'I-start_location', 'I-start_location', 'B-loca_start_num']
# ------------------------------------------------
# 29965. sentence: {start_location: deborah street} {loca_start_num: 1} to {end_location: enzo sereni} {loca_end_num: 12}, {difficulty: difficult but rewarding} {route_length: 15.5 km}
# tokens: ['deborah', 'street', '1', 'to', 'enzo', 'sereni', '12', ',', 'difficult', 'but', 'rewarding', '15.5', 'km']
# bio_tags: ['B-start_location', 'I-start_location', 'B-loca_start_num', 'O', 'B-end_location', 'I-end_location', 'B-loca_end_num', 'O', 'B-difficulty', 'I-difficulty', 'I-difficulty', 'B-route_length', 'I-route_length']
# ------------------------------------------------
# 29966. sentence: planning weekend run need ideas
# tokens: ['planning', 'weekend', 'run', 'need', 'ideas']
# bio_tags: ['O', 'O', 'O', 'O', 'O']
# ------------------------------------------------
# 29967. sentence: {difficulty: very hard} run {route_length: 19.0 km}
# tokens: ['very', 'hard', 'run', '19.0', 'km']
# bio_tags: ['B-difficulty', 'I-difficulty', 'O', 'B-route_length', 'I-route_length']
# ------------------------------------------------
# 29968. sentence: need route for tomorrow morning run
# tokens: ['need', 'route', 'for', 'tomorrow', 'morning', 'run']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'O']
# ------------------------------------------------
# 29969. sentence: Coach says {route_length: 7.5 kilometers} {difficulty: slightly challenging} run, got anything from {start_location: allenby street} {loca_start_num: 46}?
# tokens: ['Coach', 'says', '7.5', 'kilometers', 'slightly', 'challenging', 'run,', 'got', 'anything', 'from', 'allenby', 'street', '46', '?']
# bio_tags: ['O', 'O', 'B-route_length', 'I-route_length', 'B-difficulty', 'I-difficulty', 'O', 'O', 'O', 'O', 'B-start_location', 'I-start_location', 'B-loca_start_num', 'O']
# ------------------------------------------------
# 29970. sentence: Create a route that spans {route_length: 6.0 km}.
# tokens: ['Create', 'a', 'route', 'that', 'spans', '6.0', 'km', '.']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'B-route_length', 'I-route_length', 'O']
# ------------------------------------------------
# 29971. sentence: looking for {difficulty: challenging} running path {route_length: 7.0 km} from {start_location: this spot} to {end_location: meah shearim street} {loca_end_num: 29}
# tokens: ['looking', 'for', 'challenging', 'running', 'path', '7.0', 'km', 'from', 'this', 'spot', 'to', 'meah', 'shearim', 'street', '29']
# bio_tags: ['O', 'O', 'B-difficulty', 'O', 'O', 'B-route_length', 'I-route_length', 'O', 'B-start_location', 'I-start_location', 'O', 'B-end_location', 'I-end_location', 'I-end_location', 'B-loca_end_num']
# ------------------------------------------------
# 29972. sentence: want route from {start_location: agricultural station} that's not too hard
# tokens: ['want', 'route', 'from', 'agricultural', 'station', "that's", 'not', 'too', 'hard']
# bio_tags: ['O', 'O', 'O', 'B-start_location', 'I-start_location', 'O', 'O', 'O', 'O']
# ------------------------------------------------
# 29973. sentence: {start_location: zalman shazar street} {loca_start_num: 68} to {end_location: yissachar} {loca_end_num: 91}, not too difficult
# tokens: ['zalman', 'shazar', 'street', '68', 'to', 'yissachar', '91', ',', 'not', 'too', 'difficult']
# bio_tags: ['B-start_location', 'I-start_location', 'I-start_location', 'B-loca_start_num', 'O', 'B-end_location', 'B-loca_end_num', 'O', 'O', 'O', 'O']
# ------------------------------------------------
# 29974. sentence: {route_length: 3.5 km} {difficulty: somewhat tough} path from {start_location: washington street} {loca_start_num: 86} to {end_location: haayala} {loca_end_num: 57}
# tokens: ['3.5', 'km', 'somewhat', 'tough', 'path', 'from', 'washington', 'street', '86', 'to', 'haayala', '57']
# bio_tags: ['B-route_length', 'I-route_length', 'B-difficulty', 'I-difficulty', 'O', 'O', 'B-start_location', 'I-start_location', 'B-loca_start_num', 'O', 'B-end_location', 'B-loca_end_num']
# ------------------------------------------------
# 29975. sentence: {start_location: ha'ayin het street} {loca_start_num: 2} to {end_location: hazayit street} {loca_end_num: 88}, make it {route_length: long distance} and {difficulty: challenging}
# tokens: ["ha'ayin", 'het', 'street', '2', 'to', 'hazayit', 'street', '88', ',', 'make', 'it', 'long', 'distance', 'and', 'challenging']
# bio_tags: ['B-start_location', 'I-start_location', 'I-start_location', 'B-loca_start_num', 'O', 'B-end_location', 'I-end_location', 'B-loca_end_num', 'O', 'O', 'O', 'B-route_length', 'I-route_length', 'O', 'B-difficulty']
# ------------------------------------------------
# 29976. sentence: {start_location: jerusalem prize street} {loca_start_num: 36} to {end_location: megiddo} {loca_end_num: 34}, {route_length: 19.0 kilometers} {difficulty: somewhat tough}
# tokens: ['jerusalem', 'prize', 'street', '36', 'to', 'megiddo', '34', ',', '19.0', 'kilometers', 'somewhat', 'tough']
# bio_tags: ['B-start_location', 'I-start_location', 'I-start_location', 'B-loca_start_num', 'O', 'B-end_location', 'B-loca_end_num', 'O', 'B-route_length', 'I-route_length', 'B-difficulty', 'I-difficulty']
# ------------------------------------------------
# 29977. sentence: Legs are toast, need a flat {route_length: 3.0 kilometers} route from {start_location: uri zvi greenberg street} {loca_start_num: 74}
# tokens: ['Legs', 'are', 'toast,', 'need', 'a', 'flat', '3.0', 'kilometers', 'route', 'from', 'uri', 'zvi', 'greenberg', 'street', '74']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'O', 'B-route_length', 'I-route_length', 'O', 'O', 'B-start_location', 'I-start_location', 'I-start_location', 'I-start_location', 'B-loca_start_num']
# ------------------------------------------------
# 29978. sentence: I want a running route starting at {start_location: levinsky} {loca_start_num: 55} and covering {route_length: 19.0 kilometers}.
# tokens: ['I', 'want', 'a', 'running', 'route', 'starting', 'at', 'levinsky', '55', 'and', 'covering', '19.0', 'kilometers', '.']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-start_location', 'B-loca_start_num', 'O', 'O', 'B-route_length', 'I-route_length', 'O']
# ------------------------------------------------
# 29979. sentence: need route starting {start_location: linoy ashram} ending {end_location: desert spring street} {loca_end_num: 98}
# tokens: ['need', 'route', 'starting', 'linoy', 'ashram', 'ending', 'desert', 'spring', 'street', '98']
# bio_tags: ['O', 'O', 'O', 'B-start_location', 'I-start_location', 'O', 'B-end_location', 'I-end_location', 'I-end_location', 'B-loca_end_num']
# ------------------------------------------------
# 29980. sentence: need {difficulty: hard} route for my mom
# tokens: ['need', 'hard', 'route', 'for', 'my', 'mom']
# bio_tags: ['O', 'B-difficulty', 'O', 'O', 'O', 'O']
# ------------------------------------------------
# 29981. sentence: {start_location: habima} {loca_start_num: 26} to {end_location: around here}, {difficulty: very hard} {route_length: 1 km} please and thank you!
# tokens: ['habima', '26', 'to', 'around', 'here', ',', 'very', 'hard', '1', 'km', 'please', 'and', 'thank', 'you!']
# bio_tags: ['B-start_location', 'B-loca_start_num', 'O', 'B-end_location', 'I-end_location', 'O', 'B-difficulty', 'I-difficulty', 'B-route_length', 'I-route_length', 'O', 'O', 'O', 'O']
# ------------------------------------------------
# 29982. sentence: help plan my first 5k route
# tokens: ['help', 'plan', 'my', 'first', '5k', 'route']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'O']
# ------------------------------------------------
# 29983. sentence: {route_length: 950 meters} {difficulty: very hard} track from {start_location: harotem street} {loca_start_num: 4} to {end_location: jaffa gate} {loca_end_num: 80}
# tokens: ['950', 'meters', 'very', 'hard', 'track', 'from', 'harotem', 'street', '4', 'to', 'jaffa', 'gate', '80']
# bio_tags: ['B-route_length', 'I-route_length', 'B-difficulty', 'I-difficulty', 'O', 'O', 'B-start_location', 'I-start_location', 'B-loca_start_num', 'O', 'B-end_location', 'I-end_location', 'B-loca_end_num']
# ------------------------------------------------
# 29984. sentence: Where should I run today?
# tokens: ['Where', 'should', 'I', 'run', 'today?']
# bio_tags: ['O', 'O', 'O', 'O', 'O']
# ------------------------------------------------
# 29985. sentence: {difficulty: extreme difficulty} from {start_location: eilat street}
# tokens: ['extreme', 'difficulty', 'from', 'eilat', 'street']
# bio_tags: ['B-difficulty', 'I-difficulty', 'O', 'B-start_location', 'I-start_location']
# ------------------------------------------------
# 29986. sentence: running track suggestions?
# tokens: ['running', 'track', 'suggestions?']
# bio_tags: ['O', 'O', 'O']
# ------------------------------------------------
# 29987. sentence: tourist needs running recommendations
# tokens: ['tourist', 'needs', 'running', 'recommendations']
# bio_tags: ['O', 'O', 'O', 'O']
# ------------------------------------------------
# 29988. sentence: need {route_length: 17.5 kilometers} track
# tokens: ['need', '17.5', 'kilometers', 'track']
# bio_tags: ['O', 'B-route_length', 'I-route_length', 'O']
# ------------------------------------------------
# 29989. sentence: Prepping for race day from {start_location: ramle market} {loca_start_num: 41}
# tokens: ['Prepping', 'for', 'race', 'day', 'from', 'ramle', 'market', '41']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'B-start_location', 'I-start_location', 'B-loca_start_num']
# ------------------------------------------------
# 29990. sentence: Need a route that includes {end_location: galil street} {loca_end_num: 8}, around {route_length: 1-3 km}
# tokens: ['Need', 'a', 'route', 'that', 'includes', 'galil', 'street', '8', ',', 'around', '1-3', 'km']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'B-end_location', 'I-end_location', 'B-loca_end_num', 'O', 'O', 'B-route_length', 'I-route_length']
# ------------------------------------------------
# 29991. sentence: Looking for a scenic route that's approximately {route_length: 11.0 km} and {difficulty: flat and easy} - my mom is visiting and wants to go for a walk
# tokens: ['Looking', 'for', 'a', 'scenic', 'route', "that's", 'approximately', '11.0', 'km', 'and', 'flat', 'and', 'easy', '-', 'my', 'mom', 'is', 'visiting', 'and', 'wants', 'to', 'go', 'for', 'a', 'walk']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-route_length', 'I-route_length', 'O', 'B-difficulty', 'I-difficulty', 'I-difficulty', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ------------------------------------------------
# 29992. sentence: need {difficulty: very easy} morning run
# tokens: ['need', 'very', 'easy', 'morning', 'run']
# bio_tags: ['O', 'B-difficulty', 'I-difficulty', 'O', 'O']
# ------------------------------------------------
# 29993. sentence: Long run day - need a {difficulty: very hard} {route_length: 10.0 kilometers} route from {start_location: golan street} {loca_start_num: 75}
# tokens: ['Long', 'run', 'day', '-', 'need', 'a', 'very', 'hard', '10.0', 'kilometers', 'route', 'from', 'golan', 'street', '75']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'O', 'B-difficulty', 'I-difficulty', 'B-route_length', 'I-route_length', 'O', 'O', 'B-start_location', 'I-start_location', 'B-loca_start_num']
# ------------------------------------------------
# 29994. sentence: competitive runner need {difficulty: extreme difficulty} track {route_length: 13.0 kilometers} from {start_location: rachel hameshoreret street} {loca_start_num: 24} to {end_location: nahal taninim} {loca_end_num: 92}
# tokens: ['competitive', 'runner', 'need', 'extreme', 'difficulty', 'track', '13.0', 'kilometers', 'from', 'rachel', 'hameshoreret', 'street', '24', 'to', 'nahal', 'taninim', '92']
# bio_tags: ['O', 'O', 'O', 'B-difficulty', 'I-difficulty', 'O', 'B-route_length', 'I-route_length', 'O', 'B-start_location', 'I-start_location', 'I-start_location', 'B-loca_start_num', 'O', 'B-end_location', 'I-end_location', 'B-loca_end_num']
# ------------------------------------------------
# 29995. sentence: need run starting at {start_location: hatamar street} {loca_start_num: 90} that is {difficulty: not hard}
# tokens: ['need', 'run', 'starting', 'at', 'hatamar', 'street', '90', 'that', 'is', 'not', 'hard']
# bio_tags: ['O', 'O', 'O', 'O', 'B-start_location', 'I-start_location', 'B-loca_start_num', 'O', 'O', 'B-difficulty', 'I-difficulty']
# ------------------------------------------------
# 29996. sentence: Need a {difficulty: flat and easy} training route that's about {route_length: 18.0 kilometers} starting from {start_location: ramban} {loca_start_num: 32} and ending at {end_location: shlomzion hamalka street} {loca_end_num: 25} - preparing for an upcoming marathon
# tokens: ['Need', 'a', 'flat', 'and', 'easy', 'training', 'route', "that's", 'about', '18.0', 'kilometers', 'starting', 'from', 'ramban', '32', 'and', 'ending', 'at', 'shlomzion', 'hamalka', 'street', '25', '-', 'preparing', 'for', 'an', 'upcoming', 'marathon']
# bio_tags: ['O', 'O', 'B-difficulty', 'I-difficulty', 'I-difficulty', 'O', 'O', 'O', 'O', 'B-route_length', 'I-route_length', 'O', 'O', 'B-start_location', 'B-loca_start_num', 'O', 'O', 'O', 'B-end_location', 'I-end_location', 'I-end_location', 'B-loca_end_num', 'O', 'O', 'O', 'O', 'O', 'O']
# ------------------------------------------------
# 29997. sentence: Got 30 mins - where should I run from {start_location: yissachar} {loca_start_num: 75}?
# tokens: ['Got', '30', 'mins', '-', 'where', 'should', 'I', 'run', 'from', 'yissachar', '75', '?']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-start_location', 'B-loca_start_num', 'O']
# ------------------------------------------------
# 29998. sentence: Looking for drinking fountains on my {route_length: moderate distance} run from {start_location: rashi} {loca_start_num: 10}
# tokens: ['Looking', 'for', 'drinking', 'fountains', 'on', 'my', 'moderate', 'distance', 'run', 'from', 'rashi', '10']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'O', 'B-route_length', 'I-route_length', 'O', 'O', 'B-start_location', 'B-loca_start_num']
# ------------------------------------------------
# 29999. sentence: wheres good for evening jog?
# tokens: ['wheres', 'good', 'for', 'evening', 'jog?']
# bio_tags: ['O', 'O', 'O', 'O', 'O']
# ------------------------------------------------
# 30000. sentence: senior runner need route from {start_location: harav kook} {loca_start_num: 87}
# tokens: ['senior', 'runner', 'need', 'route', 'from', 'harav', 'kook', '87']
# bio_tags: ['O', 'O', 'O', 'O', 'O', 'B-start_location', 'I-start_location', 'B-loca_start_num']
# ------------------------------------------------
# ****************************************************************************************************
#                                             DONE!
# ****************************************************************************************************

# %%
import random
import pandas as pd

# %%
for obj in after_bio:
    obj['tokens'] = ', '.join(obj['tokens'])  # Convert list to string
    obj['bio_tags'] = ', '.join(obj['bio_tags'])  # Convert list to string

# Create DataFrame
df = pd.DataFrame(after_bio)

# Save the DataFrame to a CSV file
df.to_csv(file_name, index=False)

# Download the file in Google Colab
from google.colab import files
files.download(file_name)

print("*"*100)
print("                                            DONE!")
print("*"*100)
# Out:
# ****************************************************************************************************
#                                             DONE!
# ****************************************************************************************************

# %% [markdown]
# load the file for self checking
